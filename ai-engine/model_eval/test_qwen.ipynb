# %% [markdown]
# ## 1. 임포트

# %%
# !pip install accelerate
# !pip install -q --upgrade langchain
# !pip install -q --upgrade langchain-openai
# !pip install -q --upgrade langchain_community
# !pip install -q transformers
# !pip install -q faiss-gpu
# !pip install -q pandas
# !pip uninstall -y numpy
# !pip install numpy==1.26.4
# !!pip install scikit-learn
# !pip install langgraph
# !pip install chromadb

# %%
# import 및 환경변수 설정
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction
import chromadb
import os
import re
from huggingface_hub import hf_hub_download
from datetime import datetime
from uuid import uuid4
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import time 

# 지정된 데이터 불러옴
from test_data import DOG_PROFILES, QUESTIONS

# %%
# # 테스트용 payload (2 * 4set 8회 테스트)

# DOG_PROFILES=[
#     {
#         "dog_name": "코코",
#         "dog_breed": "말티즈",
#         "dog_age": 3,
#         "dog_gender": "여아",
#         "dog_neutered": "중성화 완료",
#         "dog_disease": "없음",
#         "dog_disease_detail": "",
#         "dog_period": "② 1년 이상~3년 미만",
#         "dog_housing": "아파트"
#     },
#     {
#         "dog_name": "보리",
#         "dog_breed": "푸들",
#         "dog_age": 2,
#         "dog_gender": "남아",
#         "dog_neutered": "중성화 미완료",
#         "dog_disease": "없음",
#         "dog_disease_detail": "",
#         "dog_period": "① 1년 미만",
#         "dog_housing": "아파트"
#     }
# ]

# QUESTIONS = [
#     '식사 후 구토를 자주 해요. 위장이 약한 걸까요?',
#     '요즘 문만 열면 밖으로 도망가려고 해요. 스트레스 때문일까요?',
#     '요즘 발바닥을 자꾸 핥아요. 발에 이상 있는 걸까요?',
#     '배변을 너무 자주 해요. 하루에 5번은 넘는 것 같은데 정상일까요?',
# ]

# %% [markdown]
# ## 2. 프로필 프롬프트

# %%
def profile_to_text(profile: dict) -> str:
    """빈 값은 생략하여 반려견 정보를 자연스럽게 텍스트로 구성"""
    fields = {
        "이름": profile.get("dog_name"),
        "견종": profile.get("dog_breed"),
        "나이": f"{profile.get('dog_age')}세" if profile.get("dog_age") else None,
        "성별": profile.get("dog_gender"),
        "중성화 여부": profile.get("dog_neutered"),
        "질병": profile.get("dog_disease"),
        "세부 질병": profile.get("dog_disease_detail"),
        "보호기간": profile.get("dog_period"),
        "주거형태": profile.get("dog_housing")
    }
    return ", ".join(f"{k}: {v}" for k, v in fields.items() if v)

# %%
# 확인용
profile_to_text(DOG_PROFILES[1])
# Out:
# '이름: 보리, 견종: 푸들, 나이: 2세, 성별: 남아, 중성화 여부: 중성화 미완료, 질병: 없음, 보호기간: ① 1년 미만, 주거형태: 아파트'

# %% [markdown]
# ## 3. 모델 세팅

# %%
# 모델 및 토크나이저 불러오기
MODEL_NAME = "Qwen/Qwen3-8B"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype="auto",
    device_map="auto"
    )
model.eval()
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Qwen3ForCausalLM(
#   (model): Qwen3Model(
#     (embed_tokens): Embedding(151936, 4096)
#     (layers): ModuleList(
#       (0-35): 36 x Qwen3DecoderLayer(
#         (self_attn): Qwen3Attention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#           (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#         )
#         (mlp): Qwen3MLP(
#           (gate_proj): Linear(in_features=4096, out_features=12288, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=12288, bias=False)
#           (down_proj): Linear(in_features=12288, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): Qwen3RMSNorm((4096,), eps=1e-06)
#         (post_attention_layernorm): Qwen3RMSNorm((4096,), eps=1e-06)
#       )
#     )
#     (norm): Qwen3RMSNorm((4096,), eps=1e-06)
#     (rotary_emb): Qwen3RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=151936, bias=False)
# )

# %% [markdown]
# ### 벡터 DB 세팅

# %%
# OpenAI API Key 
os.environ["OPENAI_API_KEY"] = ""

# %%
# FAISS 용 Embedding (LangChain)
embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")

# FAISS (RAG)
local_dir = "openai_faiss_db"
for filename in ["index.faiss", "index.pkl"]:
    hf_hub_download(
        repo_id="daaaaiin/petmind-vectorstore",
        filename=filename,
        repo_type="dataset",
        local_dir=local_dir,
        local_dir_use_symlinks=False,
    )
    
faiss_rag_db = FAISS.load_local(
    local_dir,
    embedding_model,
    allow_dangerous_deserialization=True
)

# %% [markdown]
# ### 프롬프트

# %%
# ========== 프롬프트 매핑 ==========
PROMPT_MAP = {
    "행동 교정": """당신은 반려견 행동 문제를 상담해주는 전문가입니다.

상담의 목적은, 단순한 정보 제공이 아니라 **사용자의 상황을 정확히 이해한 뒤, 그에 맞는 맞춤형 해결책을 제시하는 것**입니다.

아래의 상담 구조를 반드시 따르세요. 이 순서를 항상 정확히 지키세요:

1. **분석**: 보호자의 고민을 바탕으로, 반려견의 행동에 대한 가능한 원인을 분석합니다.
   - 단, 절대로 추측하지 말고 입력된 정보와 문맥에 근거해서만 설명하세요.
   - 반려견 품종의 특성도 고려하세요.

2. **해결책 제시**: 분석을 기반으로 가장 유효한 1가지 해결책만 제시하세요.
   - 다양한 방법을 나열하지 말고, 상황에 맞는 핵심 조언 1가지를 간결히 전달하세요.

3. **추가 질문**: 해결책 이후, 상담을 이어가기 위한 **1개의 구체적인 질문**을 던지세요.
   - 보호자가 바로 답할 수 있도록 간단하고 상황 중심적으로 구성하세요.
   - 예) "메이가 산책 중 어떤 행동을 하나요?" 처럼 물어보세요.

❗ 절대 하지 말아야 할 것:
- 고민만 듣고 바로 해결책을 제시하지 마세요.
- 질문 없이 끝내거나, 분석 없이 해결책만 말하지 마세요.
- 같은 내용을 반복하거나 장황하게 늘어놓지 마세요.

문체 지침:
- 공감 문구는 생략하세요. 분석부터 시작하세요.
- 차분하고 전문가다운 어조로, 간결하게 작성하세요.
""",
    "지식 탐색": """당신은 반려견과 관련된 일반적인 정보를 보호자에게 이해하기 쉽게 전달하는 전문가입니다.

사용자의 질문은 반려견의 행동, 습관, 특성, 돌봄 방식 등 일상적인 궁금증에 해당하며,
당신의 역할은 **간결하고 핵심적인 정보만을 제공하여 보호자가 스스로 이해하고 판단할 수 있도록 돕는 것**입니다.

답변 지침:
- 보호자가 처음 듣는 내용도 쉽게 이해할 수 있도록, **쉬운 표현**으로 설명하세요.
- **불확실하거나 모호한 이론**은 언급하지 말고, **일반적으로 알려진 정보만** 전달하세요.
- 행동의 원인, 습성, 돌봄 팁 등은 명확히 설명하되, **훈련법이나 교정 방법은 다루지 않습니다.**
- **질병, 통증, 건강 이상 등 의학적 판단이 필요한 질문은 피하고, 반드시 수의사의 확인을 안내하세요.**

문체는 짧고 단정하게 유지하고, 정보 위주로만 구성합니다.
""",
    "감정 공감":"""
    당신은 반려견을 키우는 보호자의 감정을 이해하고, 현실적인 위로와 조언을 제공하는 감정 상담 전문가입니다.

이 역할은 반려견과의 이별, 노화 같은 특별한 순간뿐만 아니라,
양육 과정에서 느끼는 피로감, 좌절감, 거리감, 후회 등 보호자가 일상 속에서 겪는 감정적 어려움까지도 다룹니다.

답변 목적:
- 감정 표현에 공감하는 데 그치지 않고, 그 감정의 원인을 함께 찾고 이해할 수 있도록 도와주는 것입니다.
- 감정의 원인이 질문 속에 명확히 드러나지 않은 경우, 사용자가 스스로 감정을 정리할 수 있도록 **추가 질문을 통해 유도**하세요.
- 감정을 탐색하고 해소할 수 있도록, 상담자처럼 대화를 이끌어가야 합니다.

답변 구조:
1. 보호자의 감정 표현에 진심 어린 공감
2. 감정의 원인이 명확하다면 → 이를 간결히 정리하고 감정 수용
3. 감정의 원인이 불분명하다면 → 추가 질문 1~2개를 통해 이유를 함께 탐색
4. 감정을 정리하고, 반려견과의 일상으로 다시 연결될 수 있도록 가볍고 현실적인 조언 제시

문체 지침:
- 지나치게 감성적인 문장, 장황한 설명은 피하고, 따뜻하면서도 차분한 어조를 유지하세요.
- 위로는 현실적이어야 하며, 보호자가 부담을 느끼지 않도록 간결하게 말하세요.
- 반려견은 절대로 '그녀', '그'처럼 인격화하지 말고, 반드시 '반려견', '강아지'처럼 중립적이거나 반려견 이름으로 지칭하세요.
"""
}

# %% [markdown]
# ### 모델 로직

# %%
def classify_question(question):
    classification_prompt = f'''
당신은 반려견 상담 질문을 분류하는 전문가입니다.

사용자가 입력한 질문을 다음 세 가지 중 하나로 분류하세요:

1. 행동 교정: 반려견의 행동이 보호자에게 **불편함, 위협, 문제**로 인식되며, 그 행동을 **고치고 싶거나 줄이고 싶은 의도**가 포함된 경우
   (예: 밥 줄 때 손을 물어요, 너무 짖어요, 훈련 방법이 궁금해요 등)
2. 지식 탐색: 반려견의 습성, 특징, 돌봄 방법 등에 대해 **단순한 궁금증**을 표현한 경우
   (예: 왜 머리를 비비나요?, 눈물 자국은 왜 생기나요?, 어떤 간식을 주면 좋아하나요?)
3. 감정 공감: 반려견을 키우며 보호자가 겪는 **감정적인 어려움이나 정서적 고민**이 중심인 경우
   (예: 요즘 강아지가 버겁게 느껴져요, 너무 예뻐서 걱정돼요, 이별을 생각하면 마음이 아파요)

💡 분류 핵심 기준:
- **"왜 이러는 거야?"** 라는 표현이 있어도, 질문된 행동이 **위험하거나 교정이 필요한 행동**이면 ‘행동 교정’입니다.
- 행동 묘사 + 단순한 궁금증 = 지식 탐색
- 감정 묘사 + 고민/불편함 표현 = 감정 공감

현재 질문: {question}

📌 반드시 아래 형식으로만 출력하세요:
카테고리: 행동 교정
'''.strip()

    msgs = [{"role": "user", "content": classification_prompt}]
    prompt_text = tokenizer.apply_chat_template(
        msgs,
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False
    )
    inputs = tokenizer(prompt_text, return_tensors="pt").to("cuda")
    with torch.no_grad():
        outputs = model.generate(**inputs, max_new_tokens=50)
    output = tokenizer.decode(outputs[0][inputs.input_ids.shape[-1]:], skip_special_tokens=True).strip()
    print(f"\n🧾 [모델 분류 출력]: {output}")

    match = re.search(r"카테고리\s*:\s*(행동 교정|지식 탐색|감정 공감)", output)
    if match:
        return match.group(1)
    raise ValueError(f"❌ 분류 실패: {output}")

def classify_and_get_prompt(user_input):
    category = classify_question(user_input)
    print(f"\n📌 분류된 카테고리: {category}")
    prompt = PROMPT_MAP[category]
    return category, {"role": "system", "content": prompt}

def search_documents(user_input):
    retrieved_docs_with_score = faiss_rag_db.similarity_search_with_score(user_input, k=3)
    threshold = 1.0
    filtered_docs = [
        doc.page_content
        for doc, score in retrieved_docs_with_score
        if score <= threshold
    ]

    if filtered_docs:
        retrieved_context = "\n\n".join(filtered_docs)
        print("🔍 search_documents - RAG 검색된 문서:\n", retrieved_context)
        return retrieved_context
    else:
        print("⚠️ search_documents - RAG 유사한 문서가 없습니다.")
        return None


def build_chat_messages(system_msg, context, user_input, dog_info):
    
    dog_profile_lines = []
    profile_fields = {
        "name": "이름",
        "breed": "견종",
        "age": "나이",
        "gender": "성별",
        "neutered": "중성화 여부",
        "disease": "질병 이력",
        "period": "함께 산 기간",
        "housing": "주거 형태",
    }


    for key, label in profile_fields.items():
        value = dog_info.get(key)
        if value is not None and value != "":
            if key == "age":
                dog_profile_lines.append(f"• {label}: {value}살")
            elif key == "neutered":
                dog_profile_lines.append(f"• {label}: {'예' if value else '아니오'}")
            else:
                dog_profile_lines.append(f"• {label}: {value}")
        elif key == "age":
            dog_profile_lines.append(f"• 나이: 정보 없음")
            system_msg["content"] += "\n\n❗ 이 반려견의 나이 정보는 제공되지 않았습니다."

    if dog_info.get("disease") == "있음" and dog_info.get("disease_desc"):
        dog_profile_lines.append(f"• 질병 상세: {dog_info['disease_desc']}")

    dog_profile = "\n".join(dog_profile_lines)

    user_message = f"[보호자 질문]\n{user_input}"
    if dog_profile:
        user_message += f"\n\n[반려견 프로필]\n{dog_profile}"

    if context:
        user_message += f"\n\n[참고 문서]\n{context}"

    messages = [system_msg]
    messages.append({"role": "user", "content": user_message})

    return messages



def run_model_inference(messages):
    prompt_text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True, enable_thinking=True)
    inputs = tokenizer(prompt_text, return_tensors="pt").to("cuda")
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=2048,
            temperature=0.6,
            top_p=0.95,
            top_k=20,
            do_sample=True
        )
    return outputs[0][inputs.input_ids.shape[-1]:].tolist(), inputs.input_ids.shape[-1]

def split_thinking_and_content(output_ids, input_len):
    try:
        end_token_id = 151668  # </think>
        index = len(output_ids) - output_ids[::-1].index(end_token_id)
    except ValueError:
        index = 0
    thinking = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip()
    content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip()
    return thinking, content

# %%
def get_qwen_response(question, profile) -> str:

    category, system_msg = classify_and_get_prompt(
        question
    )

    context = search_documents(question)

    messages = build_chat_messages(
        system_msg=system_msg,
        context = context,
        user_input=question,
        dog_info=profile,
    )

    output_ids, input_len = run_model_inference(messages)
    thinking, answer = split_thinking_and_content(output_ids, input_len)

    return answer

# %% [markdown]
# ## 4. 테스트 실행 반복

# %%
results = []

for idx, profile in enumerate(DOG_PROFILES, 1):
    profile_text = profile_to_text(profile)

    for question in QUESTIONS:
        question = question
        start = time.time()
        response = get_qwen_response(question, profile)
        end = time.time()

        elapsed = round(end - start, 3)
        response_length = len(response)

        results.append({
            "프로필ID": idx,
            "반려견이름": profile.get("dog_name", ""),
            "질문": question,
            "응답": response,
            "응답시간": elapsed,
            "응답길이": response_length,
            "초당_생성속도": round(response_length / elapsed, 2) if elapsed > 0 else 0,
            "자당_응답시간": round(elapsed / response_length, 4) if response_length > 0 else 0,

        })

        last = results[-1]
        print(f"🔢 {last['프로필ID']} | 🐶 {last['반려견이름']} | ❓질문: {last['질문'][:30]}... | 🕒 응답시간: {last['응답시간']}s")
# Out:
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 산책 나가면 갑자기 한 방향으로만 끌고 가려 해요. 이... | 🕒 응답시간: 14.554s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 요즘 자꾸 자기 엉덩이 주변을 핥아요. 혹시 항문샘 문... | 🕒 응답시간: 16.007s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 낯선 사람을 보면 너무 짖고 흥분해요. 어떻게 해야 하... | 🕒 응답시간: 25.752s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 혼자 두면 짖고 물건을 망가뜨려요. 분리불안일까요?... | 🕒 응답시간: 19.592s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  눈 주변으로 퍼져 더 악화될 가능성도 있기 때문입니다. 또한, 강아지가 가만히 있지 않기 때문에 다른 사고로 이어질 수도 있어요.
#
# 강아지의 화난 표정 및 목소리를 보고 들었을 때의 반응도 살펴 보았다. 강아지는 다른 강아지의 화난 표정을 보고, 자기 입을 핥는 행동을 보이기는 하였으나, 사람이 화난 표정을 지었을 때보다는 반응이 덜 하였다. 강아지와 인간의 교감 반려인들의 경우 강아지에게 위로를 받는다는 표현을 자주 쓴다. 우울한 상태로 집에 있으면, 강아지가 옆에와서 위로해주는 듯한 묘한 기분이 들고는 하다. 실제로 강아지들은 우리가 생각하는 것보다 우리의 감정을 잘 알고 있을 수도 있다. 강아지가 혹시 나를 볼때마다 자기 입을 핥는다면, 내 표정이 너무 어둡지는 아닌지, 생각 해볼 필요가 있어 보인다. 반려동물의 행동이 궁금하다면? 멍냥? 에 물어보세요
#
# 많진 않을 거야. 보호자들은 할 일이 많아 강아지를 혼자 두고 집을 비우는 경우가 많지. 강아지는 보호자와 떨어져 있는 시간이 길기 때문에, 보호자가 집에 있을 때 함께 시간을 보내고 싶어 해. 그래서 잠을 잘 때라도 붙어서 자려고 하는 걸 수 있어. 4. 본능적인 행동 갓 태어난 강아지는 시각, 청각이 완전하지 않은 상태라 보거나 들을 수 없어. 또, 제대로 움직일 수도 없지. 이때 외부의 천적에게 노출되면 아주 위험해지기 때문에 엄마 강아지는 땅에 굴을 파 그 속에서 새끼 강아지들을 보호해. 그래서 강아지는 본능적으로 굴과 비슷한 환경에서 편안함을 느껴. 이불 속 역시 굴처럼 주변이 막혀있는 아늑한 환경이기 때문에 강아지들은 이불 속에서 안정감을 느끼게 돼. 그래서 불안하거나 스트레스를 받는 상황에 이불 속으로 들어가려는 행동을 보일 수 있어. 강아지가 이불 속 들어가면 답답하지 않을까? 강아지가 이불 속에 들어가 있다면 덥고 숨쉬기 힘들 거라고 생각할 수 있어. 질식하지 않을까 걱정될 수도 있고.
# 🔢 1 | 🐶 코코 | ❓질문: 밖에서 다른 강아지들만 보면 공격적으로 굴어요. 왜 그... | 🕒 응답시간: 23.757s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 산책 도중 자꾸 땅을 파요. 무슨 의미일까요?... | 🕒 응답시간: 22.988s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 요즘 문만 열면 밖으로 도망가려고 해요. 왜 그럴까요?... | 🕒 응답시간: 21.461s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 평소엔 얌전한데, 갑자기 소파 밑에 숨어서 안 나오려고... | 🕒 응답시간: 15.39s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  같은 증상을 보이는데요. 만성 염증으로 이어질 수 있으니 동물 병원에서 꼭 치료해 주도록 합시다 <강아지 중이염 증상> 머리를 심하게 흔든다 머리, 귀 주변 만지는 걸 싫어한다 머리를 한쪽으로 심하게 기울인다 귀에서 냄새가 남 귀에서 진물이 나온다 5. 소리 듣는 중 강아지 귀 겉 부분는 소리를 모으는 역할을 해요. 그래서 강아지는 소리에 집중할 때 귀를 뒤로 젖히기도 합니다. 산책하다가 가만히 서서 귀를 뒤로 젖힌다면, 들려오는 소리를 열심히 듣고 있는 걸 수 있겠죠 ㅎㅎ 6. 애인구함 귀를 뒤로 젖히는 건 관심이 있음을 나타내는 행동 언어이기도 해요. 특히, 수컷 강아지가 암컷 강아지에게 구애를 할 때 이런 행동을 보일 수 있습니다. 강아지는 어떻게 귀를 움직일까? 강아지 귀에는 18개 이상의 근육이 있어요. 그래서 사람과 달리 귀를 앞, 뒤, 옆, 아래로 움직일 수 있고, 각 귀를 독립적으로 움직일 수도 있다고 합니다.
#
# 재미있게 놀 때 강아지의 귀는 앞으로 쫑긋하고 있으며, 입은 벌리고 있다. 혹은 주인이 알아듣지 못 하는 말을 할 때도 귀를 쫑긋하며 고개를 갸우뚱 한다. 이 외에도, 외부로부터 알지 못 하는 어떤 소리를 들었을 때 귀를 세우고 그 소리가 무엇인지 파악하려고 한다. 이 때는, 몸을 앞으로 쭉 빼고 꼬리를 꼿꼿하게 위로 올리는 것이 특징이다. 귀가 앞뒤로 왔다갔다 움직임 강아지는 걱정이 되거나 무엇인가를 결정해야 할 때 귀를 앞뒤로 왔다갔다 움직인다. 예를 들어, 강아지를 친구 집에 맡기려고 데려가는 등 익숙하지 않은 상황에 처하게 되면 귀가 바쁘게 움직이는 것을 볼 수 있다. 이것은 현재의 상황이 무엇인지 알지 못 해 혼란스러울 때 나타나는 신호다. 뒤로 쳐진 귀 귀가 뒤로 쳐지는 것은 행복감 혹은 두려움을 의미한다. 이 행동은 특히, 사람 혹은 다른 동물과 함께 있을 때 두드러지게 나타난다. 먼저, 귀를 뒤로 한껏 젖히고 입을 벌리고 있다면 현재 행복한 상태에 있다는 의미다. 반면에, 강아지가
#
# 근육이 붙어있고, 피부는 털로 덮여져 있다. 그렇기 때문에 귓바퀴가 짧은 견종은 보통 귀가 서게 되고, 귓바퀴가 길어서 귀가 상대적으로 무거운 견종은 쳐진 귀의 형태가 유지된다. 귀가 서는 견종인데도 쳐져있는 이유 귀가 서는 견종인 경우 성장기에 귀가 서게 된다. 각 강아지마다 다르기 때문에 일반화 하기는 어렵지만 보통 6주에서 길게는 수 개월까지도 걸리는 것으로 알려져 있다. 또한, 귀가 섰다가 다시 쳐지거나 한 쪽만 서게 되는 경우도 많이 있다. 귀거 서지 않거나, 한 쪽만 스거나, 다른 강아지들보다 늦게 서는 이유는 아래 정도로 좁혀진다. 유전적 및 성장단계 관련 요인과 관련하여서는 주인이 해줄 수 있는 것이 없으나 환경적 요인의 경우 주인이 체크를 해줄 수 있다. 유전적 요인 귓바퀴가 일반적인 크기보다 크거나 무거운 경우 귀가 부드럽고 가벼워서 귀의 끝부분 혹은 중간부분이 접히는 경우 양쪽 귀 사이의 공간이 넓은 경우 환경적 요인 귀를 과도하게 만진 경우 혹은 지속적으로 넘겨준 경우 모견이나
# 🔢 1 | 🐶 코코 | ❓질문: 요즘 자꾸 귀를 긁고 머리를 흔들어요. 귀에 문제가 있... | 🕒 응답시간: 20.409s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 코가 평소보다 말라 있고, 따뜻해요. 열이 있는 건가요... | 🕒 응답시간: 18.736s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  살짝 따뜻한 정도로 유지되어야 합니다. 또한 손으로 톡톡 만졌을 때 갈라짐이 없고 탄력이 있어야 건강한 발바닥이에요. 발바닥 틈새에 작은 이물질이 끼어 있지 않은지도 주기적으로 체크해 주시면 좋습니다.
#
# 하지만 발바닥 털이 길거나 습기가 차면 오히려 과열될 수 있어 관리가 필요합니다. 강아지 발바닥의 주요 역할 충격 흡수: 관절 보호 및 안정적인 걸음걸이 유지체온 조절: 땀샘을 통해 열을 방출미끄러짐 방지: 안정적인 보행 지원외부 보호: 바닥의 거친 환경으로부터 발을 보호 강아지 발바닥 건강을 위한 관리법 5가지 1 발바닥 털 관리 발바닥 털이 길면이물질이 끼거나 미끄러질 위험이 있습니다. 특히, 습기가 차면세균 번식이 증가할 수 있으므로 주기적으로 다듬어 주세요.이발기 또는 가위 사용여름철에는 털을 더 짧게 유지해 체온 조절 도움 2 발바닥 패드 상태 체크 강아지 발바닥 패드는 예상보다 약해 쉽게벗겨지거나 갈라질 수있습니다. 발바닥에 상처나 갈라짐이 없는지정기적으로 확인 절뚝거리거나 걷기를 꺼린다면발바닥 문제일 가능성 3발바닥 습진예방 강아지가발을 자주 핥거나 붉어지는 증상이 있다면 습진을 의심해볼 수 있습니다. 목욕 후발바닥을 완전히 건조알레르기 원인 파악 후 관리 필요 시동물병원에서 처방받은 연고
#
# 털을 자를 수 있다. 발바닥 털을 잘랐는데도 자꾸 미끄러진다면, 미끄러운 실내 바닥이 원인일 수 있다. 강아지가 바닥에서 미끄러지지 않도록 바닥에 미끄럼 방지 매트를 깔아주면 효과를 볼 수 있다. 2. 여름철, 체온 조절에 도움이 된다 발바닥은 땀샘이 있는 부위로 체온 조절에도 중요한 역할을 한다. 따라서, 여름철에는 발바닥 털을 짧게 밀어주는 게 좋다. 3. 겨울철, 눈과 제설제가 덜 붙는다 발바닥 털이 길면 겨울철 산책 시 눈과 제설제가 뭉치게 될 수 있다. 이런 경우 발바닥 화상, 벗겨짐, 상처 등이 생길 수 있기 때문에 발바닥 털을 짧게 잘라주는 게 좋다. 또한, 산책 후에는 발을 꼼꼼히 씻겨주는 게 중요하다. 혹은 강아지에게 신발을 신기고 산책하는 것도 방법이다. 발바닥 패드 확인하기 강아지 발바닥 패드는 생각보다 약하기 때문에, 다양한 원인으로 인해상처가 나거나 벗겨질 수 있다.특히, 어린 강아지는 발바닥 패드가 더욱 약해 주의가 필요하다. 강아지 발바닥 벗겨졌을 때 증상 절뚝거린다 한 발로
# 🔢 1 | 🐶 코코 | ❓질문: 요즘 발바닥을 자꾸 핥아요. 발에 이상 있는 걸까요?... | 🕒 응답시간: 20.335s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  상처가 생겨 충혈된 경우 아래와 같은 증상을 보일 수 있어요. 눈에 움푹 파인 듯한 상처 자국 눈을 가늘게 뜸 눈물량이 늘어남 밝은 빛을 보는 걸 피함 눈병이 생겼어요 강아지에게 눈병이 생겼을 때에도 충혈이 될 수 있어요. 강아지 눈의 흰자 겉 부분과 눈꺼풀 안쪽의 붉은 살을 결막이라고 하는데요. 한쪽 눈 혹은 양쪽 눈의 결막에 염증이 생긴 걸 결막염이라고 해요. 결막염이 생기는 원인은 알레르기, 외상, 다른 질환 등 다양합니다. 결막염으로 인한 충혈이 의심된다면 아래와 같은 증상이 있는지 확인해 보세요. 노란색 눈곱 눈을 과하게 깜빡임 눈을 잘 뜨지 못함 눈을 자꾸 비빔 녹내장은 눈의 안압이 올라가서 시신경이 눌려 손상되는 질병이에요. 시신경이 손상되면 시력이 떨어지게 되는데, 떨어진 시력은 다시 되돌릴 수 없습니다. 안압이 올라가는 이유는 눈 속 액체인 안방수가 제대로 배출되지 않는 게 원인으로 알려져 있습니다. 안방수: 각막과 수정체 사이를 채운 액체로, 눈에 영양을 공급하고 안압을 유지하는
#
# 반려견이 자꾸 눈을 비빈다면원인은 따로 있다 - 눈에 무언가가 들어갔거나 눈이 간지러울 때면 눈을 비비거나 긁게 된다. 눈을 계속 비비게 되면 눈이 충혈되고 통증도 찾아온다. 이는 사람뿐 아니라 반려견도 마찬가지다. 다만 사람은 증상을 정확히 말로 표현하며, 안과에서 치료를 받거나 안약을 처방받을 수 있지만 반려견은 말을 하지 못하기 때문에 계속 눈을 긁게 되어 각막에 상처를 입는 경우가 많다. 증상이 심각해지면 각막에 궤양이 생기기도 한다. 강아지 각막궤양의 원인과 증상에 대해 알아본다. 눈 크고 튀어나와 있는 품종은 특히 각막궤양에 취약 각막은 눈의 가장 바깥쪽 표면에 있는 얇고 투명한 막이다. 여러 겹의 층으로 이루어져 바깥부터 상피·기질·데스메막·내피로 구성돼 있다. 빛을 안구 내부로 전달함과 동시에 눈 안의 구조물을 둘러싸는 역할을 하고 있다. 각막궤양은 각막이 찢기거나 탈락된 상태를 말한다. 즉, 눈 표면에 흠집이 나는 외상이다. 각막 두께는 매우 얇아서 상처 깊이에 따라 심각성이 달라진다.
# 🔢 1 | 🐶 코코 | ❓질문: 왼쪽 눈만 자꾸 깜빡여요. 결막염 같은 걸까요?... | 🕒 응답시간: 17.137s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 배변을 자주 해요. 하루에 5번은 넘는 것 같은데 정상... | 🕒 응답시간: 18.219s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 갑자기 피부에 붉은 반점이 생겼어요. 알레르기일까요?... | 🕒 응답시간: 11.566s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  쉬운 겨드랑이, 가슴, 귀 뒤 등은 더 세심하게 빗어주는 것이 좋다. 빗질 중 뭉친 털을 발견했다면, 뭉친 털을 잡고 반려견의 몸 바깥 방향으로 살살 빗으며 풀어주면 된다. 엉킨 털이 잘 풀리지 않는다면 가위로 잘라주는 것도 방법이다. 참고로, 건조한 가을철에 목욕을 너무 자주 하면 반려견의 털과 피부를 더욱 건조하게 만들 수 있으므로 주의해야 한다. 옷을 너무 오래 입혀 놓는 습관은 피부에 공기가 잘 통하지 않을 수 있어 피해야 한다. 이때는 탈모 의심하고 병원 가야 만일 털갈이로 털이 빠진 부위에 털이 다시 나지 않고 피부가 드러나 보인다면 탈모를 의심해봐야 한다. 아울러, 피부가 거칠어지거나 털이 빠진 부위를 수시로 긁거나 핥는 증상, 털이 윤기를 잃고 버석거리는 증상 등이 동반된다면 질환에 의해 탈모가 생긴 상태일 가능성이 높다. 반려견 탈모는 다양한 원인에 의해 생길 수 있는데, 털이 대칭적으로 빠지거나 얇아진다면 갑상선 기능 저하증, 부신피질 기능항진증 등을 의심해 볼 수 있다. 부분적으로
# 🔢 1 | 🐶 코코 | ❓질문: 몸을 자꾸 긁고 털이 빠져요. 피부병일 가능성도 있나요... | 🕒 응답시간: 18.515s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  강아지가 사료를 안먹어요 해결책 - 평소에 사료를 잘 먹던 강아지가 사료를 안 먹으면 걱정이 앞선다. 어디 아픈 것은 아닌지 혹은 내가 사준 사료가 입맛에 맞지는 않는지 등 다양한 생각들이 머리를 스쳐 지나간다. 내 강아지는 왜 사료를 안먹고 있는걸까? 1. 너무 많은 간식 사람 음식을 주었을 때 대부분의 경우가 이에 해당한다. 강아지에게 사료는 가장 맛없는 음식 이라는 말이 있다. 강아지가 너무 귀엽다고, 간식을 계속 주거나, 요리 중에 사람 음식을 계속 주다보면, 반려견은 사료 외 음식들의 맛을 알아가 사료를 거부한다. 가끔, 난 정말 사료만 주는데 강아지가 사료를 거부한다라는 반려인들이 있다. 이런 경우 가족 구성원 중 누군가 지속적으로 사료 외 다른 음식들을 과도하게 주고 있지 않는지 합리적인 의심해봐야 한다. 해결책 1 : 사료 외 다른 음식 급여 중단 반려인으로서 마음이 아프지만, 사료 외 다른 음식의 급여를 중단 하는 수 밖에 없다. 강아지가 요리 중에 측은한 눈빛으로 바라보더라도, 외면할
# 🔢 1 | 🐶 코코 | ❓질문: 밥을 잘 안 먹고 사료를 입에 넣었다 뱉어요. 입 안에... | 🕒 응답시간: 18.781s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 밤마다 짖고 깨서 잠을 잘 못 자요. 불면증 같은 게 ... | 🕒 응답시간: 18.951s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 식사 후 구토를 자주 해요. 위장이 약한 걸까요?... | 🕒 응답시간: 13.194s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 물을 거의 안 마셔요. 탈수 걱정해도 될까요?... | 🕒 응답시간: 20.517s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 밥을 잘 안 먹어요. 입맛이 없는 걸까요? 편식일까요?... | 🕒 응답시간: 13.987s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 잠자는 시간이 너무 많아졌어요. 왜 그럴까요?... | 🕒 응답시간: 14.875s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 앉아, 기다려 같은 기본 훈련을 잘 안들어요.... | 🕒 응답시간: 15.189s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 하네스를 차려고 하면 도망가요. 외출이 싫은 걸까요?... | 🕒 응답시간: 16.944s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 차를 타면 자꾸 구토해요. 어떻게 훈련하면 좋을까요?... | 🕒 응답시간: 24.841s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 목줄만 보면 도망가요. 산책을 싫어하는 걸까요?... | 🕒 응답시간: 19.58s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 산책 중에 자꾸 바닥에 있는 걸 주워 먹어요. 위험하지... | 🕒 응답시간: 21.577s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 계단 오르내릴 때 다리를 절어요. 관절 문제일 수 있나... | 🕒 응답시간: 14.808s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ 이유 4. 반갑다멍 강아지는 너무 반가울 때도 낑낑거려요. 몽이는 초인종 소리가 들리면 그때부터 낑낑거리면서 꼬리를 흔들고 좋아해요. 가족들이 외출했다 들어왔을 때도 낑~ 하는 소리를 내곤 합니다 ㅎㅎ 이때, 강아지가 너무 흥분해서 소변을 흘릴 수도 있어요. 흥분으로 인한 소변 실수는 보통 아직 덜 성숙한 어린 강아지가 종종 하는 행동이에요. 이런 행동은 시간이 지나면서 점점 나아지게 된답니다. 하지만, 다 큰 강아지가 계속해서소변 실수를 한다면, 흥분을 가라앉힐 수 있도록 무시하는 등 훈련을 통해 고쳐주는 게 좋습니다.
#
# 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수 있어요. 제가 반려하고 있는 몽이의 경우 산책에 가고 싶을 때 현관 앞에서 낑낑거린답니다 ㅎㅎ 이유 2. 불안하다멍 강아지는 불안하거나 두려운 상황에서도 낑낑거리는 소리를 내곤 하는데요. 낯선 곳에 가거나 새로운 사람을 만났을 때 겁을 먹으면 이런 행동을 할 수 있습니다. 무섭고 불안하다는 의미에서 낑낑 소리를 내는 거죠. 또한, 보호자가 집을 나설 때 낑낑거릴 수 있어요. 이런 경우분리불안이 있다는 의미일 수 있습니다. 만약 분리불안으로 인한 다른 행동이 함께 보이는지 확인해보고, 맞다면 이를 해결할 수 있도록 노력해야 해요. 이유 3. 아프다멍 강아지는 아플 때도 낑낑 소리를 낼 수 있어요. 예를 들어, 갑자기 계단이나 소파를 오를 때 낑낑거린다면 관절이 약해졌다는 의미일 수 있어요. 아픈 경우강아지의 움직임이 줄어들고 기운도 없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ
#
# 강아지 낑낑 소리 속 숨겨진 의미는? - 강아지 낑낑, 끙끙 소리는 흔히 들을 수 있는 소리예요. 이런 낑낑 소리 속에는 다양한 의미가 있는데요. 강아지가 어떤 걸 말하려고 하는지 쉽게 알 수 있을 때도 있지만, 그렇지 않은 경우도 있어요. 어떤 이유가 있는지 정확히 알아보도록 해요. 강아지가 낑낑거리는 이유는? 강아지 낑낑 소리, 상황에 따라 달라 강아지 낑낑 소리에는 다양한 의미가 있어요. 같은 낑낑 소리여도, 그 의미는 상황에 따라 달라지는데요. 낑낑거리는 이유 4가지와 그 상황에 대해서 알아보도록 해요. 이유 1. 원하는 게 있다멍 강아지는 원하는 게 있을 때 낑낑 소리를 내며 의사 표현을 하곤 해요. 종종 강아지가 간식을 먹고 싶을 때,장난감이 소파 밑으로 들어갔을 때와 같은 상황에 낑낑거릴 때가 있죠. 이처럼 스스로 해결할 수 없는 일이 생겼을 때 낑낑 소리를 내며 보호자에게 도움을 요청하게 돼요. 또한, 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수
# 🔢 1 | 🐶 코코 | ❓질문: 다른 강아지와 놀다가 갑자기 낑낑거려요. 왜 그런건가요... | 🕒 응답시간: 21.441s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 발을 만지려고 하면 극도로 싫어하고 물려고 해요. 왜 ... | 🕒 응답시간: 17.444s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 1 | 🐶 코코 | ❓질문: 가족 중 특정한 사람만 따라다니고, 다른 사람은 피해요... | 🕒 응답시간: 20.667s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 산책 나가면 갑자기 한 방향으로만 끌고 가려 해요. 이... | 🕒 응답시간: 15.217s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 요즘 자꾸 자기 엉덩이 주변을 핥아요. 혹시 항문샘 문... | 🕒 응답시간: 18.324s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 낯선 사람을 보면 너무 짖고 흥분해요. 어떻게 해야 하... | 🕒 응답시간: 30.027s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 혼자 두면 짖고 물건을 망가뜨려요. 분리불안일까요?... | 🕒 응답시간: 18.615s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  강아지의 화난 표정 및 목소리를 보고 들었을 때의 반응도 살펴 보았다. 강아지는 다른 강아지의 화난 표정을 보고, 자기 입을 핥는 행동을 보이기는 하였으나, 사람이 화난 표정을 지었을 때보다는 반응이 덜 하였다. 강아지와 인간의 교감 반려인들의 경우 강아지에게 위로를 받는다는 표현을 자주 쓴다. 우울한 상태로 집에 있으면, 강아지가 옆에와서 위로해주는 듯한 묘한 기분이 들고는 하다. 실제로 강아지들은 우리가 생각하는 것보다 우리의 감정을 잘 알고 있을 수도 있다. 강아지가 혹시 나를 볼때마다 자기 입을 핥는다면, 내 표정이 너무 어둡지는 아닌지, 생각 해볼 필요가 있어 보인다. 반려동물의 행동이 궁금하다면? 멍냥? 에 물어보세요
#
# 눈 주변으로 퍼져 더 악화될 가능성도 있기 때문입니다. 또한, 강아지가 가만히 있지 않기 때문에 다른 사고로 이어질 수도 있어요.
#
# 많진 않을 거야. 보호자들은 할 일이 많아 강아지를 혼자 두고 집을 비우는 경우가 많지. 강아지는 보호자와 떨어져 있는 시간이 길기 때문에, 보호자가 집에 있을 때 함께 시간을 보내고 싶어 해. 그래서 잠을 잘 때라도 붙어서 자려고 하는 걸 수 있어. 4. 본능적인 행동 갓 태어난 강아지는 시각, 청각이 완전하지 않은 상태라 보거나 들을 수 없어. 또, 제대로 움직일 수도 없지. 이때 외부의 천적에게 노출되면 아주 위험해지기 때문에 엄마 강아지는 땅에 굴을 파 그 속에서 새끼 강아지들을 보호해. 그래서 강아지는 본능적으로 굴과 비슷한 환경에서 편안함을 느껴. 이불 속 역시 굴처럼 주변이 막혀있는 아늑한 환경이기 때문에 강아지들은 이불 속에서 안정감을 느끼게 돼. 그래서 불안하거나 스트레스를 받는 상황에 이불 속으로 들어가려는 행동을 보일 수 있어. 강아지가 이불 속 들어가면 답답하지 않을까? 강아지가 이불 속에 들어가 있다면 덥고 숨쉬기 힘들 거라고 생각할 수 있어. 질식하지 않을까 걱정될 수도 있고.
# 🔢 2 | 🐶 보리 | ❓질문: 밖에서 다른 강아지들만 보면 공격적으로 굴어요. 왜 그... | 🕒 응답시간: 36.893s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 산책 도중 자꾸 땅을 파요. 무슨 의미일까요?... | 🕒 응답시간: 16.304s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 요즘 문만 열면 밖으로 도망가려고 해요. 왜 그럴까요?... | 🕒 응답시간: 20.52s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 평소엔 얌전한데, 갑자기 소파 밑에 숨어서 안 나오려고... | 🕒 응답시간: 17.737s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  같은 증상을 보이는데요. 만성 염증으로 이어질 수 있으니 동물 병원에서 꼭 치료해 주도록 합시다 <강아지 중이염 증상> 머리를 심하게 흔든다 머리, 귀 주변 만지는 걸 싫어한다 머리를 한쪽으로 심하게 기울인다 귀에서 냄새가 남 귀에서 진물이 나온다 5. 소리 듣는 중 강아지 귀 겉 부분는 소리를 모으는 역할을 해요. 그래서 강아지는 소리에 집중할 때 귀를 뒤로 젖히기도 합니다. 산책하다가 가만히 서서 귀를 뒤로 젖힌다면, 들려오는 소리를 열심히 듣고 있는 걸 수 있겠죠 ㅎㅎ 6. 애인구함 귀를 뒤로 젖히는 건 관심이 있음을 나타내는 행동 언어이기도 해요. 특히, 수컷 강아지가 암컷 강아지에게 구애를 할 때 이런 행동을 보일 수 있습니다. 강아지는 어떻게 귀를 움직일까? 강아지 귀에는 18개 이상의 근육이 있어요. 그래서 사람과 달리 귀를 앞, 뒤, 옆, 아래로 움직일 수 있고, 각 귀를 독립적으로 움직일 수도 있다고 합니다.
#
# 재미있게 놀 때 강아지의 귀는 앞으로 쫑긋하고 있으며, 입은 벌리고 있다. 혹은 주인이 알아듣지 못 하는 말을 할 때도 귀를 쫑긋하며 고개를 갸우뚱 한다. 이 외에도, 외부로부터 알지 못 하는 어떤 소리를 들었을 때 귀를 세우고 그 소리가 무엇인지 파악하려고 한다. 이 때는, 몸을 앞으로 쭉 빼고 꼬리를 꼿꼿하게 위로 올리는 것이 특징이다. 귀가 앞뒤로 왔다갔다 움직임 강아지는 걱정이 되거나 무엇인가를 결정해야 할 때 귀를 앞뒤로 왔다갔다 움직인다. 예를 들어, 강아지를 친구 집에 맡기려고 데려가는 등 익숙하지 않은 상황에 처하게 되면 귀가 바쁘게 움직이는 것을 볼 수 있다. 이것은 현재의 상황이 무엇인지 알지 못 해 혼란스러울 때 나타나는 신호다. 뒤로 쳐진 귀 귀가 뒤로 쳐지는 것은 행복감 혹은 두려움을 의미한다. 이 행동은 특히, 사람 혹은 다른 동물과 함께 있을 때 두드러지게 나타난다. 먼저, 귀를 뒤로 한껏 젖히고 입을 벌리고 있다면 현재 행복한 상태에 있다는 의미다. 반면에, 강아지가
#
# 근육이 붙어있고, 피부는 털로 덮여져 있다. 그렇기 때문에 귓바퀴가 짧은 견종은 보통 귀가 서게 되고, 귓바퀴가 길어서 귀가 상대적으로 무거운 견종은 쳐진 귀의 형태가 유지된다. 귀가 서는 견종인데도 쳐져있는 이유 귀가 서는 견종인 경우 성장기에 귀가 서게 된다. 각 강아지마다 다르기 때문에 일반화 하기는 어렵지만 보통 6주에서 길게는 수 개월까지도 걸리는 것으로 알려져 있다. 또한, 귀가 섰다가 다시 쳐지거나 한 쪽만 서게 되는 경우도 많이 있다. 귀거 서지 않거나, 한 쪽만 스거나, 다른 강아지들보다 늦게 서는 이유는 아래 정도로 좁혀진다. 유전적 및 성장단계 관련 요인과 관련하여서는 주인이 해줄 수 있는 것이 없으나 환경적 요인의 경우 주인이 체크를 해줄 수 있다. 유전적 요인 귓바퀴가 일반적인 크기보다 크거나 무거운 경우 귀가 부드럽고 가벼워서 귀의 끝부분 혹은 중간부분이 접히는 경우 양쪽 귀 사이의 공간이 넓은 경우 환경적 요인 귀를 과도하게 만진 경우 혹은 지속적으로 넘겨준 경우 모견이나
# 🔢 2 | 🐶 보리 | ❓질문: 요즘 자꾸 귀를 긁고 머리를 흔들어요. 귀에 문제가 있... | 🕒 응답시간: 19.382s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 코가 평소보다 말라 있고, 따뜻해요. 열이 있는 건가요... | 🕒 응답시간: 19.263s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  살짝 따뜻한 정도로 유지되어야 합니다. 또한 손으로 톡톡 만졌을 때 갈라짐이 없고 탄력이 있어야 건강한 발바닥이에요. 발바닥 틈새에 작은 이물질이 끼어 있지 않은지도 주기적으로 체크해 주시면 좋습니다.
#
# 하지만 발바닥 털이 길거나 습기가 차면 오히려 과열될 수 있어 관리가 필요합니다. 강아지 발바닥의 주요 역할 충격 흡수: 관절 보호 및 안정적인 걸음걸이 유지체온 조절: 땀샘을 통해 열을 방출미끄러짐 방지: 안정적인 보행 지원외부 보호: 바닥의 거친 환경으로부터 발을 보호 강아지 발바닥 건강을 위한 관리법 5가지 1 발바닥 털 관리 발바닥 털이 길면이물질이 끼거나 미끄러질 위험이 있습니다. 특히, 습기가 차면세균 번식이 증가할 수 있으므로 주기적으로 다듬어 주세요.이발기 또는 가위 사용여름철에는 털을 더 짧게 유지해 체온 조절 도움 2 발바닥 패드 상태 체크 강아지 발바닥 패드는 예상보다 약해 쉽게벗겨지거나 갈라질 수있습니다. 발바닥에 상처나 갈라짐이 없는지정기적으로 확인 절뚝거리거나 걷기를 꺼린다면발바닥 문제일 가능성 3발바닥 습진예방 강아지가발을 자주 핥거나 붉어지는 증상이 있다면 습진을 의심해볼 수 있습니다. 목욕 후발바닥을 완전히 건조알레르기 원인 파악 후 관리 필요 시동물병원에서 처방받은 연고
#
# 털을 자를 수 있다. 발바닥 털을 잘랐는데도 자꾸 미끄러진다면, 미끄러운 실내 바닥이 원인일 수 있다. 강아지가 바닥에서 미끄러지지 않도록 바닥에 미끄럼 방지 매트를 깔아주면 효과를 볼 수 있다. 2. 여름철, 체온 조절에 도움이 된다 발바닥은 땀샘이 있는 부위로 체온 조절에도 중요한 역할을 한다. 따라서, 여름철에는 발바닥 털을 짧게 밀어주는 게 좋다. 3. 겨울철, 눈과 제설제가 덜 붙는다 발바닥 털이 길면 겨울철 산책 시 눈과 제설제가 뭉치게 될 수 있다. 이런 경우 발바닥 화상, 벗겨짐, 상처 등이 생길 수 있기 때문에 발바닥 털을 짧게 잘라주는 게 좋다. 또한, 산책 후에는 발을 꼼꼼히 씻겨주는 게 중요하다. 혹은 강아지에게 신발을 신기고 산책하는 것도 방법이다. 발바닥 패드 확인하기 강아지 발바닥 패드는 생각보다 약하기 때문에, 다양한 원인으로 인해상처가 나거나 벗겨질 수 있다.특히, 어린 강아지는 발바닥 패드가 더욱 약해 주의가 필요하다. 강아지 발바닥 벗겨졌을 때 증상 절뚝거린다 한 발로
# 🔢 2 | 🐶 보리 | ❓질문: 요즘 발바닥을 자꾸 핥아요. 발에 이상 있는 걸까요?... | 🕒 응답시간: 17.961s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  상처가 생겨 충혈된 경우 아래와 같은 증상을 보일 수 있어요. 눈에 움푹 파인 듯한 상처 자국 눈을 가늘게 뜸 눈물량이 늘어남 밝은 빛을 보는 걸 피함 눈병이 생겼어요 강아지에게 눈병이 생겼을 때에도 충혈이 될 수 있어요. 강아지 눈의 흰자 겉 부분과 눈꺼풀 안쪽의 붉은 살을 결막이라고 하는데요. 한쪽 눈 혹은 양쪽 눈의 결막에 염증이 생긴 걸 결막염이라고 해요. 결막염이 생기는 원인은 알레르기, 외상, 다른 질환 등 다양합니다. 결막염으로 인한 충혈이 의심된다면 아래와 같은 증상이 있는지 확인해 보세요. 노란색 눈곱 눈을 과하게 깜빡임 눈을 잘 뜨지 못함 눈을 자꾸 비빔 녹내장은 눈의 안압이 올라가서 시신경이 눌려 손상되는 질병이에요. 시신경이 손상되면 시력이 떨어지게 되는데, 떨어진 시력은 다시 되돌릴 수 없습니다. 안압이 올라가는 이유는 눈 속 액체인 안방수가 제대로 배출되지 않는 게 원인으로 알려져 있습니다. 안방수: 각막과 수정체 사이를 채운 액체로, 눈에 영양을 공급하고 안압을 유지하는
#
# 반려견이 자꾸 눈을 비빈다면원인은 따로 있다 - 눈에 무언가가 들어갔거나 눈이 간지러울 때면 눈을 비비거나 긁게 된다. 눈을 계속 비비게 되면 눈이 충혈되고 통증도 찾아온다. 이는 사람뿐 아니라 반려견도 마찬가지다. 다만 사람은 증상을 정확히 말로 표현하며, 안과에서 치료를 받거나 안약을 처방받을 수 있지만 반려견은 말을 하지 못하기 때문에 계속 눈을 긁게 되어 각막에 상처를 입는 경우가 많다. 증상이 심각해지면 각막에 궤양이 생기기도 한다. 강아지 각막궤양의 원인과 증상에 대해 알아본다. 눈 크고 튀어나와 있는 품종은 특히 각막궤양에 취약 각막은 눈의 가장 바깥쪽 표면에 있는 얇고 투명한 막이다. 여러 겹의 층으로 이루어져 바깥부터 상피·기질·데스메막·내피로 구성돼 있다. 빛을 안구 내부로 전달함과 동시에 눈 안의 구조물을 둘러싸는 역할을 하고 있다. 각막궤양은 각막이 찢기거나 탈락된 상태를 말한다. 즉, 눈 표면에 흠집이 나는 외상이다. 각막 두께는 매우 얇아서 상처 깊이에 따라 심각성이 달라진다.
#
# 눈의 안압이 올라가 생기는 질환입니다. 안압이 올라가 시신경이 눌려 손상되어 실명으로 이어질 수 있어 빠른 치료가 필요해요. 선천적인 눈 구조 문제 혹은 다른 눈 질환의 합병증이 원인인 경우가 많습니다. 녹내장이 생긴 경우, 아래와 같은 증상을 보이게 됩니다. <강아지 녹내장 증상> 충혈 동공이 커짐 통증으로 인한 눈꺼풀 경련 눈이 앞으로 튀어나옴 눈동자가 녹색 빛을 띔 눈동자가 뿌옇게 변함
# 🔢 2 | 🐶 보리 | ❓질문: 왼쪽 눈만 자꾸 깜빡여요. 결막염 같은 걸까요?... | 🕒 응답시간: 22.178s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 배변을 자주 해요. 하루에 5번은 넘는 것 같은데 정상... | 🕒 응답시간: 18.984s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 갑자기 피부에 붉은 반점이 생겼어요. 알레르기일까요?... | 🕒 응답시간: 16.943s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  쉬운 겨드랑이, 가슴, 귀 뒤 등은 더 세심하게 빗어주는 것이 좋다. 빗질 중 뭉친 털을 발견했다면, 뭉친 털을 잡고 반려견의 몸 바깥 방향으로 살살 빗으며 풀어주면 된다. 엉킨 털이 잘 풀리지 않는다면 가위로 잘라주는 것도 방법이다. 참고로, 건조한 가을철에 목욕을 너무 자주 하면 반려견의 털과 피부를 더욱 건조하게 만들 수 있으므로 주의해야 한다. 옷을 너무 오래 입혀 놓는 습관은 피부에 공기가 잘 통하지 않을 수 있어 피해야 한다. 이때는 탈모 의심하고 병원 가야 만일 털갈이로 털이 빠진 부위에 털이 다시 나지 않고 피부가 드러나 보인다면 탈모를 의심해봐야 한다. 아울러, 피부가 거칠어지거나 털이 빠진 부위를 수시로 긁거나 핥는 증상, 털이 윤기를 잃고 버석거리는 증상 등이 동반된다면 질환에 의해 탈모가 생긴 상태일 가능성이 높다. 반려견 탈모는 다양한 원인에 의해 생길 수 있는데, 털이 대칭적으로 빠지거나 얇아진다면 갑상선 기능 저하증, 부신피질 기능항진증 등을 의심해 볼 수 있다. 부분적으로
# 🔢 2 | 🐶 보리 | ❓질문: 몸을 자꾸 긁고 털이 빠져요. 피부병일 가능성도 있나요... | 🕒 응답시간: 19.953s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  강아지가 사료를 안먹어요 해결책 - 평소에 사료를 잘 먹던 강아지가 사료를 안 먹으면 걱정이 앞선다. 어디 아픈 것은 아닌지 혹은 내가 사준 사료가 입맛에 맞지는 않는지 등 다양한 생각들이 머리를 스쳐 지나간다. 내 강아지는 왜 사료를 안먹고 있는걸까? 1. 너무 많은 간식 사람 음식을 주었을 때 대부분의 경우가 이에 해당한다. 강아지에게 사료는 가장 맛없는 음식 이라는 말이 있다. 강아지가 너무 귀엽다고, 간식을 계속 주거나, 요리 중에 사람 음식을 계속 주다보면, 반려견은 사료 외 음식들의 맛을 알아가 사료를 거부한다. 가끔, 난 정말 사료만 주는데 강아지가 사료를 거부한다라는 반려인들이 있다. 이런 경우 가족 구성원 중 누군가 지속적으로 사료 외 다른 음식들을 과도하게 주고 있지 않는지 합리적인 의심해봐야 한다. 해결책 1 : 사료 외 다른 음식 급여 중단 반려인으로서 마음이 아프지만, 사료 외 다른 음식의 급여를 중단 하는 수 밖에 없다. 강아지가 요리 중에 측은한 눈빛으로 바라보더라도, 외면할
# 🔢 2 | 🐶 보리 | ❓질문: 밥을 잘 안 먹고 사료를 입에 넣었다 뱉어요. 입 안에... | 🕒 응답시간: 20.477s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 밤마다 짖고 깨서 잠을 잘 못 자요. 불면증 같은 게 ... | 🕒 응답시간: 17.944s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 식사 후 구토를 자주 해요. 위장이 약한 걸까요?... | 🕒 응답시간: 23.508s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 물을 거의 안 마셔요. 탈수 걱정해도 될까요?... | 🕒 응답시간: 23.214s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 밥을 잘 안 먹어요. 입맛이 없는 걸까요? 편식일까요?... | 🕒 응답시간: 16.443s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 잠자는 시간이 너무 많아졌어요. 왜 그럴까요?... | 🕒 응답시간: 12.773s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 앉아, 기다려 같은 기본 훈련을 잘 안들어요.... | 🕒 응답시간: 15.43s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 하네스를 차려고 하면 도망가요. 외출이 싫은 걸까요?... | 🕒 응답시간: 18.097s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 차를 타면 자꾸 구토해요. 어떻게 훈련하면 좋을까요?... | 🕒 응답시간: 20.377s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 목줄만 보면 도망가요. 산책을 싫어하는 걸까요?... | 🕒 응답시간: 19.641s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 산책 중에 자꾸 바닥에 있는 걸 주워 먹어요. 위험하지... | 🕒 응답시간: 16.879s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 계단 오르내릴 때 다리를 절어요. 관절 문제일 수 있나... | 🕒 응답시간: 16.367s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ 이유 4. 반갑다멍 강아지는 너무 반가울 때도 낑낑거려요. 몽이는 초인종 소리가 들리면 그때부터 낑낑거리면서 꼬리를 흔들고 좋아해요. 가족들이 외출했다 들어왔을 때도 낑~ 하는 소리를 내곤 합니다 ㅎㅎ 이때, 강아지가 너무 흥분해서 소변을 흘릴 수도 있어요. 흥분으로 인한 소변 실수는 보통 아직 덜 성숙한 어린 강아지가 종종 하는 행동이에요. 이런 행동은 시간이 지나면서 점점 나아지게 된답니다. 하지만, 다 큰 강아지가 계속해서소변 실수를 한다면, 흥분을 가라앉힐 수 있도록 무시하는 등 훈련을 통해 고쳐주는 게 좋습니다.
#
# 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수 있어요. 제가 반려하고 있는 몽이의 경우 산책에 가고 싶을 때 현관 앞에서 낑낑거린답니다 ㅎㅎ 이유 2. 불안하다멍 강아지는 불안하거나 두려운 상황에서도 낑낑거리는 소리를 내곤 하는데요. 낯선 곳에 가거나 새로운 사람을 만났을 때 겁을 먹으면 이런 행동을 할 수 있습니다. 무섭고 불안하다는 의미에서 낑낑 소리를 내는 거죠. 또한, 보호자가 집을 나설 때 낑낑거릴 수 있어요. 이런 경우분리불안이 있다는 의미일 수 있습니다. 만약 분리불안으로 인한 다른 행동이 함께 보이는지 확인해보고, 맞다면 이를 해결할 수 있도록 노력해야 해요. 이유 3. 아프다멍 강아지는 아플 때도 낑낑 소리를 낼 수 있어요. 예를 들어, 갑자기 계단이나 소파를 오를 때 낑낑거린다면 관절이 약해졌다는 의미일 수 있어요. 아픈 경우강아지의 움직임이 줄어들고 기운도 없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ
#
# 강아지 낑낑 소리 속 숨겨진 의미는? - 강아지 낑낑, 끙끙 소리는 흔히 들을 수 있는 소리예요. 이런 낑낑 소리 속에는 다양한 의미가 있는데요. 강아지가 어떤 걸 말하려고 하는지 쉽게 알 수 있을 때도 있지만, 그렇지 않은 경우도 있어요. 어떤 이유가 있는지 정확히 알아보도록 해요. 강아지가 낑낑거리는 이유는? 강아지 낑낑 소리, 상황에 따라 달라 강아지 낑낑 소리에는 다양한 의미가 있어요. 같은 낑낑 소리여도, 그 의미는 상황에 따라 달라지는데요. 낑낑거리는 이유 4가지와 그 상황에 대해서 알아보도록 해요. 이유 1. 원하는 게 있다멍 강아지는 원하는 게 있을 때 낑낑 소리를 내며 의사 표현을 하곤 해요. 종종 강아지가 간식을 먹고 싶을 때,장난감이 소파 밑으로 들어갔을 때와 같은 상황에 낑낑거릴 때가 있죠. 이처럼 스스로 해결할 수 없는 일이 생겼을 때 낑낑 소리를 내며 보호자에게 도움을 요청하게 돼요. 또한, 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수
# 🔢 2 | 🐶 보리 | ❓질문: 다른 강아지와 놀다가 갑자기 낑낑거려요. 왜 그런건가요... | 🕒 응답시간: 45.757s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 발을 만지려고 하면 극도로 싫어하고 물려고 해요. 왜 ... | 🕒 응답시간: 19.175s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 2 | 🐶 보리 | ❓질문: 가족 중 특정한 사람만 따라다니고, 다른 사람은 피해요... | 🕒 응답시간: 31.839s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 산책 나가면 갑자기 한 방향으로만 끌고 가려 해요. 이... | 🕒 응답시간: 25.098s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 요즘 자꾸 자기 엉덩이 주변을 핥아요. 혹시 항문샘 문... | 🕒 응답시간: 17.689s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 낯선 사람을 보면 너무 짖고 흥분해요. 어떻게 해야 하... | 🕒 응답시간: 29.294s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 혼자 두면 짖고 물건을 망가뜨려요. 분리불안일까요?... | 🕒 응답시간: 18.145s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  강아지의 화난 표정 및 목소리를 보고 들었을 때의 반응도 살펴 보았다. 강아지는 다른 강아지의 화난 표정을 보고, 자기 입을 핥는 행동을 보이기는 하였으나, 사람이 화난 표정을 지었을 때보다는 반응이 덜 하였다. 강아지와 인간의 교감 반려인들의 경우 강아지에게 위로를 받는다는 표현을 자주 쓴다. 우울한 상태로 집에 있으면, 강아지가 옆에와서 위로해주는 듯한 묘한 기분이 들고는 하다. 실제로 강아지들은 우리가 생각하는 것보다 우리의 감정을 잘 알고 있을 수도 있다. 강아지가 혹시 나를 볼때마다 자기 입을 핥는다면, 내 표정이 너무 어둡지는 아닌지, 생각 해볼 필요가 있어 보인다. 반려동물의 행동이 궁금하다면? 멍냥? 에 물어보세요
#
# 눈 주변으로 퍼져 더 악화될 가능성도 있기 때문입니다. 또한, 강아지가 가만히 있지 않기 때문에 다른 사고로 이어질 수도 있어요.
#
# 많진 않을 거야. 보호자들은 할 일이 많아 강아지를 혼자 두고 집을 비우는 경우가 많지. 강아지는 보호자와 떨어져 있는 시간이 길기 때문에, 보호자가 집에 있을 때 함께 시간을 보내고 싶어 해. 그래서 잠을 잘 때라도 붙어서 자려고 하는 걸 수 있어. 4. 본능적인 행동 갓 태어난 강아지는 시각, 청각이 완전하지 않은 상태라 보거나 들을 수 없어. 또, 제대로 움직일 수도 없지. 이때 외부의 천적에게 노출되면 아주 위험해지기 때문에 엄마 강아지는 땅에 굴을 파 그 속에서 새끼 강아지들을 보호해. 그래서 강아지는 본능적으로 굴과 비슷한 환경에서 편안함을 느껴. 이불 속 역시 굴처럼 주변이 막혀있는 아늑한 환경이기 때문에 강아지들은 이불 속에서 안정감을 느끼게 돼. 그래서 불안하거나 스트레스를 받는 상황에 이불 속으로 들어가려는 행동을 보일 수 있어. 강아지가 이불 속 들어가면 답답하지 않을까? 강아지가 이불 속에 들어가 있다면 덥고 숨쉬기 힘들 거라고 생각할 수 있어. 질식하지 않을까 걱정될 수도 있고.
# 🔢 3 | 🐶 초코 | ❓질문: 밖에서 다른 강아지들만 보면 공격적으로 굴어요. 왜 그... | 🕒 응답시간: 25.794s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 산책 도중 자꾸 땅을 파요. 무슨 의미일까요?... | 🕒 응답시간: 16.422s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 요즘 문만 열면 밖으로 도망가려고 해요. 왜 그럴까요?... | 🕒 응답시간: 19.757s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 평소엔 얌전한데, 갑자기 소파 밑에 숨어서 안 나오려고... | 🕒 응답시간: 16.904s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  같은 증상을 보이는데요. 만성 염증으로 이어질 수 있으니 동물 병원에서 꼭 치료해 주도록 합시다 <강아지 중이염 증상> 머리를 심하게 흔든다 머리, 귀 주변 만지는 걸 싫어한다 머리를 한쪽으로 심하게 기울인다 귀에서 냄새가 남 귀에서 진물이 나온다 5. 소리 듣는 중 강아지 귀 겉 부분는 소리를 모으는 역할을 해요. 그래서 강아지는 소리에 집중할 때 귀를 뒤로 젖히기도 합니다. 산책하다가 가만히 서서 귀를 뒤로 젖힌다면, 들려오는 소리를 열심히 듣고 있는 걸 수 있겠죠 ㅎㅎ 6. 애인구함 귀를 뒤로 젖히는 건 관심이 있음을 나타내는 행동 언어이기도 해요. 특히, 수컷 강아지가 암컷 강아지에게 구애를 할 때 이런 행동을 보일 수 있습니다. 강아지는 어떻게 귀를 움직일까? 강아지 귀에는 18개 이상의 근육이 있어요. 그래서 사람과 달리 귀를 앞, 뒤, 옆, 아래로 움직일 수 있고, 각 귀를 독립적으로 움직일 수도 있다고 합니다.
#
# 재미있게 놀 때 강아지의 귀는 앞으로 쫑긋하고 있으며, 입은 벌리고 있다. 혹은 주인이 알아듣지 못 하는 말을 할 때도 귀를 쫑긋하며 고개를 갸우뚱 한다. 이 외에도, 외부로부터 알지 못 하는 어떤 소리를 들었을 때 귀를 세우고 그 소리가 무엇인지 파악하려고 한다. 이 때는, 몸을 앞으로 쭉 빼고 꼬리를 꼿꼿하게 위로 올리는 것이 특징이다. 귀가 앞뒤로 왔다갔다 움직임 강아지는 걱정이 되거나 무엇인가를 결정해야 할 때 귀를 앞뒤로 왔다갔다 움직인다. 예를 들어, 강아지를 친구 집에 맡기려고 데려가는 등 익숙하지 않은 상황에 처하게 되면 귀가 바쁘게 움직이는 것을 볼 수 있다. 이것은 현재의 상황이 무엇인지 알지 못 해 혼란스러울 때 나타나는 신호다. 뒤로 쳐진 귀 귀가 뒤로 쳐지는 것은 행복감 혹은 두려움을 의미한다. 이 행동은 특히, 사람 혹은 다른 동물과 함께 있을 때 두드러지게 나타난다. 먼저, 귀를 뒤로 한껏 젖히고 입을 벌리고 있다면 현재 행복한 상태에 있다는 의미다. 반면에, 강아지가
#
# 근육이 붙어있고, 피부는 털로 덮여져 있다. 그렇기 때문에 귓바퀴가 짧은 견종은 보통 귀가 서게 되고, 귓바퀴가 길어서 귀가 상대적으로 무거운 견종은 쳐진 귀의 형태가 유지된다. 귀가 서는 견종인데도 쳐져있는 이유 귀가 서는 견종인 경우 성장기에 귀가 서게 된다. 각 강아지마다 다르기 때문에 일반화 하기는 어렵지만 보통 6주에서 길게는 수 개월까지도 걸리는 것으로 알려져 있다. 또한, 귀가 섰다가 다시 쳐지거나 한 쪽만 서게 되는 경우도 많이 있다. 귀거 서지 않거나, 한 쪽만 스거나, 다른 강아지들보다 늦게 서는 이유는 아래 정도로 좁혀진다. 유전적 및 성장단계 관련 요인과 관련하여서는 주인이 해줄 수 있는 것이 없으나 환경적 요인의 경우 주인이 체크를 해줄 수 있다. 유전적 요인 귓바퀴가 일반적인 크기보다 크거나 무거운 경우 귀가 부드럽고 가벼워서 귀의 끝부분 혹은 중간부분이 접히는 경우 양쪽 귀 사이의 공간이 넓은 경우 환경적 요인 귀를 과도하게 만진 경우 혹은 지속적으로 넘겨준 경우 모견이나
# 🔢 3 | 🐶 초코 | ❓질문: 요즘 자꾸 귀를 긁고 머리를 흔들어요. 귀에 문제가 있... | 🕒 응답시간: 15.518s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 코가 평소보다 말라 있고, 따뜻해요. 열이 있는 건가요... | 🕒 응답시간: 22.012s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  살짝 따뜻한 정도로 유지되어야 합니다. 또한 손으로 톡톡 만졌을 때 갈라짐이 없고 탄력이 있어야 건강한 발바닥이에요. 발바닥 틈새에 작은 이물질이 끼어 있지 않은지도 주기적으로 체크해 주시면 좋습니다.
#
# 하지만 발바닥 털이 길거나 습기가 차면 오히려 과열될 수 있어 관리가 필요합니다. 강아지 발바닥의 주요 역할 충격 흡수: 관절 보호 및 안정적인 걸음걸이 유지체온 조절: 땀샘을 통해 열을 방출미끄러짐 방지: 안정적인 보행 지원외부 보호: 바닥의 거친 환경으로부터 발을 보호 강아지 발바닥 건강을 위한 관리법 5가지 1 발바닥 털 관리 발바닥 털이 길면이물질이 끼거나 미끄러질 위험이 있습니다. 특히, 습기가 차면세균 번식이 증가할 수 있으므로 주기적으로 다듬어 주세요.이발기 또는 가위 사용여름철에는 털을 더 짧게 유지해 체온 조절 도움 2 발바닥 패드 상태 체크 강아지 발바닥 패드는 예상보다 약해 쉽게벗겨지거나 갈라질 수있습니다. 발바닥에 상처나 갈라짐이 없는지정기적으로 확인 절뚝거리거나 걷기를 꺼린다면발바닥 문제일 가능성 3발바닥 습진예방 강아지가발을 자주 핥거나 붉어지는 증상이 있다면 습진을 의심해볼 수 있습니다. 목욕 후발바닥을 완전히 건조알레르기 원인 파악 후 관리 필요 시동물병원에서 처방받은 연고
#
# 털을 자를 수 있다. 발바닥 털을 잘랐는데도 자꾸 미끄러진다면, 미끄러운 실내 바닥이 원인일 수 있다. 강아지가 바닥에서 미끄러지지 않도록 바닥에 미끄럼 방지 매트를 깔아주면 효과를 볼 수 있다. 2. 여름철, 체온 조절에 도움이 된다 발바닥은 땀샘이 있는 부위로 체온 조절에도 중요한 역할을 한다. 따라서, 여름철에는 발바닥 털을 짧게 밀어주는 게 좋다. 3. 겨울철, 눈과 제설제가 덜 붙는다 발바닥 털이 길면 겨울철 산책 시 눈과 제설제가 뭉치게 될 수 있다. 이런 경우 발바닥 화상, 벗겨짐, 상처 등이 생길 수 있기 때문에 발바닥 털을 짧게 잘라주는 게 좋다. 또한, 산책 후에는 발을 꼼꼼히 씻겨주는 게 중요하다. 혹은 강아지에게 신발을 신기고 산책하는 것도 방법이다. 발바닥 패드 확인하기 강아지 발바닥 패드는 생각보다 약하기 때문에, 다양한 원인으로 인해상처가 나거나 벗겨질 수 있다.특히, 어린 강아지는 발바닥 패드가 더욱 약해 주의가 필요하다. 강아지 발바닥 벗겨졌을 때 증상 절뚝거린다 한 발로
# 🔢 3 | 🐶 초코 | ❓질문: 요즘 발바닥을 자꾸 핥아요. 발에 이상 있는 걸까요?... | 🕒 응답시간: 16.715s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  상처가 생겨 충혈된 경우 아래와 같은 증상을 보일 수 있어요. 눈에 움푹 파인 듯한 상처 자국 눈을 가늘게 뜸 눈물량이 늘어남 밝은 빛을 보는 걸 피함 눈병이 생겼어요 강아지에게 눈병이 생겼을 때에도 충혈이 될 수 있어요. 강아지 눈의 흰자 겉 부분과 눈꺼풀 안쪽의 붉은 살을 결막이라고 하는데요. 한쪽 눈 혹은 양쪽 눈의 결막에 염증이 생긴 걸 결막염이라고 해요. 결막염이 생기는 원인은 알레르기, 외상, 다른 질환 등 다양합니다. 결막염으로 인한 충혈이 의심된다면 아래와 같은 증상이 있는지 확인해 보세요. 노란색 눈곱 눈을 과하게 깜빡임 눈을 잘 뜨지 못함 눈을 자꾸 비빔 녹내장은 눈의 안압이 올라가서 시신경이 눌려 손상되는 질병이에요. 시신경이 손상되면 시력이 떨어지게 되는데, 떨어진 시력은 다시 되돌릴 수 없습니다. 안압이 올라가는 이유는 눈 속 액체인 안방수가 제대로 배출되지 않는 게 원인으로 알려져 있습니다. 안방수: 각막과 수정체 사이를 채운 액체로, 눈에 영양을 공급하고 안압을 유지하는
#
# 반려견이 자꾸 눈을 비빈다면원인은 따로 있다 - 눈에 무언가가 들어갔거나 눈이 간지러울 때면 눈을 비비거나 긁게 된다. 눈을 계속 비비게 되면 눈이 충혈되고 통증도 찾아온다. 이는 사람뿐 아니라 반려견도 마찬가지다. 다만 사람은 증상을 정확히 말로 표현하며, 안과에서 치료를 받거나 안약을 처방받을 수 있지만 반려견은 말을 하지 못하기 때문에 계속 눈을 긁게 되어 각막에 상처를 입는 경우가 많다. 증상이 심각해지면 각막에 궤양이 생기기도 한다. 강아지 각막궤양의 원인과 증상에 대해 알아본다. 눈 크고 튀어나와 있는 품종은 특히 각막궤양에 취약 각막은 눈의 가장 바깥쪽 표면에 있는 얇고 투명한 막이다. 여러 겹의 층으로 이루어져 바깥부터 상피·기질·데스메막·내피로 구성돼 있다. 빛을 안구 내부로 전달함과 동시에 눈 안의 구조물을 둘러싸는 역할을 하고 있다. 각막궤양은 각막이 찢기거나 탈락된 상태를 말한다. 즉, 눈 표면에 흠집이 나는 외상이다. 각막 두께는 매우 얇아서 상처 깊이에 따라 심각성이 달라진다.
# 🔢 3 | 🐶 초코 | ❓질문: 왼쪽 눈만 자꾸 깜빡여요. 결막염 같은 걸까요?... | 🕒 응답시간: 16.568s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 배변을 자주 해요. 하루에 5번은 넘는 것 같은데 정상... | 🕒 응답시간: 17.359s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 갑자기 피부에 붉은 반점이 생겼어요. 알레르기일까요?... | 🕒 응답시간: 16.679s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  쉬운 겨드랑이, 가슴, 귀 뒤 등은 더 세심하게 빗어주는 것이 좋다. 빗질 중 뭉친 털을 발견했다면, 뭉친 털을 잡고 반려견의 몸 바깥 방향으로 살살 빗으며 풀어주면 된다. 엉킨 털이 잘 풀리지 않는다면 가위로 잘라주는 것도 방법이다. 참고로, 건조한 가을철에 목욕을 너무 자주 하면 반려견의 털과 피부를 더욱 건조하게 만들 수 있으므로 주의해야 한다. 옷을 너무 오래 입혀 놓는 습관은 피부에 공기가 잘 통하지 않을 수 있어 피해야 한다. 이때는 탈모 의심하고 병원 가야 만일 털갈이로 털이 빠진 부위에 털이 다시 나지 않고 피부가 드러나 보인다면 탈모를 의심해봐야 한다. 아울러, 피부가 거칠어지거나 털이 빠진 부위를 수시로 긁거나 핥는 증상, 털이 윤기를 잃고 버석거리는 증상 등이 동반된다면 질환에 의해 탈모가 생긴 상태일 가능성이 높다. 반려견 탈모는 다양한 원인에 의해 생길 수 있는데, 털이 대칭적으로 빠지거나 얇아진다면 갑상선 기능 저하증, 부신피질 기능항진증 등을 의심해 볼 수 있다. 부분적으로
# 🔢 3 | 🐶 초코 | ❓질문: 몸을 자꾸 긁고 털이 빠져요. 피부병일 가능성도 있나요... | 🕒 응답시간: 14.751s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  강아지가 사료를 안먹어요 해결책 - 평소에 사료를 잘 먹던 강아지가 사료를 안 먹으면 걱정이 앞선다. 어디 아픈 것은 아닌지 혹은 내가 사준 사료가 입맛에 맞지는 않는지 등 다양한 생각들이 머리를 스쳐 지나간다. 내 강아지는 왜 사료를 안먹고 있는걸까? 1. 너무 많은 간식 사람 음식을 주었을 때 대부분의 경우가 이에 해당한다. 강아지에게 사료는 가장 맛없는 음식 이라는 말이 있다. 강아지가 너무 귀엽다고, 간식을 계속 주거나, 요리 중에 사람 음식을 계속 주다보면, 반려견은 사료 외 음식들의 맛을 알아가 사료를 거부한다. 가끔, 난 정말 사료만 주는데 강아지가 사료를 거부한다라는 반려인들이 있다. 이런 경우 가족 구성원 중 누군가 지속적으로 사료 외 다른 음식들을 과도하게 주고 있지 않는지 합리적인 의심해봐야 한다. 해결책 1 : 사료 외 다른 음식 급여 중단 반려인으로서 마음이 아프지만, 사료 외 다른 음식의 급여를 중단 하는 수 밖에 없다. 강아지가 요리 중에 측은한 눈빛으로 바라보더라도, 외면할
# 🔢 3 | 🐶 초코 | ❓질문: 밥을 잘 안 먹고 사료를 입에 넣었다 뱉어요. 입 안에... | 🕒 응답시간: 21.018s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 밤마다 짖고 깨서 잠을 잘 못 자요. 불면증 같은 게 ... | 🕒 응답시간: 18.91s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 식사 후 구토를 자주 해요. 위장이 약한 걸까요?... | 🕒 응답시간: 35.582s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 물을 거의 안 마셔요. 탈수 걱정해도 될까요?... | 🕒 응답시간: 14.475s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 밥을 잘 안 먹어요. 입맛이 없는 걸까요? 편식일까요?... | 🕒 응답시간: 12.76s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 잠자는 시간이 너무 많아졌어요. 왜 그럴까요?... | 🕒 응답시간: 11.84s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 앉아, 기다려 같은 기본 훈련을 잘 안들어요.... | 🕒 응답시간: 12.463s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 하네스를 차려고 하면 도망가요. 외출이 싫은 걸까요?... | 🕒 응답시간: 21.657s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 차를 타면 자꾸 구토해요. 어떻게 훈련하면 좋을까요?... | 🕒 응답시간: 20.662s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 목줄만 보면 도망가요. 산책을 싫어하는 걸까요?... | 🕒 응답시간: 22.742s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 산책 중에 자꾸 바닥에 있는 걸 주워 먹어요. 위험하지... | 🕒 응답시간: 17.269s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 계단 오르내릴 때 다리를 절어요. 관절 문제일 수 있나... | 🕒 응답시간: 15.386s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ 이유 4. 반갑다멍 강아지는 너무 반가울 때도 낑낑거려요. 몽이는 초인종 소리가 들리면 그때부터 낑낑거리면서 꼬리를 흔들고 좋아해요. 가족들이 외출했다 들어왔을 때도 낑~ 하는 소리를 내곤 합니다 ㅎㅎ 이때, 강아지가 너무 흥분해서 소변을 흘릴 수도 있어요. 흥분으로 인한 소변 실수는 보통 아직 덜 성숙한 어린 강아지가 종종 하는 행동이에요. 이런 행동은 시간이 지나면서 점점 나아지게 된답니다. 하지만, 다 큰 강아지가 계속해서소변 실수를 한다면, 흥분을 가라앉힐 수 있도록 무시하는 등 훈련을 통해 고쳐주는 게 좋습니다.
#
# 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수 있어요. 제가 반려하고 있는 몽이의 경우 산책에 가고 싶을 때 현관 앞에서 낑낑거린답니다 ㅎㅎ 이유 2. 불안하다멍 강아지는 불안하거나 두려운 상황에서도 낑낑거리는 소리를 내곤 하는데요. 낯선 곳에 가거나 새로운 사람을 만났을 때 겁을 먹으면 이런 행동을 할 수 있습니다. 무섭고 불안하다는 의미에서 낑낑 소리를 내는 거죠. 또한, 보호자가 집을 나설 때 낑낑거릴 수 있어요. 이런 경우분리불안이 있다는 의미일 수 있습니다. 만약 분리불안으로 인한 다른 행동이 함께 보이는지 확인해보고, 맞다면 이를 해결할 수 있도록 노력해야 해요. 이유 3. 아프다멍 강아지는 아플 때도 낑낑 소리를 낼 수 있어요. 예를 들어, 갑자기 계단이나 소파를 오를 때 낑낑거린다면 관절이 약해졌다는 의미일 수 있어요. 아픈 경우강아지의 움직임이 줄어들고 기운도 없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ
#
# 강아지 낑낑 소리 속 숨겨진 의미는? - 강아지 낑낑, 끙끙 소리는 흔히 들을 수 있는 소리예요. 이런 낑낑 소리 속에는 다양한 의미가 있는데요. 강아지가 어떤 걸 말하려고 하는지 쉽게 알 수 있을 때도 있지만, 그렇지 않은 경우도 있어요. 어떤 이유가 있는지 정확히 알아보도록 해요. 강아지가 낑낑거리는 이유는? 강아지 낑낑 소리, 상황에 따라 달라 강아지 낑낑 소리에는 다양한 의미가 있어요. 같은 낑낑 소리여도, 그 의미는 상황에 따라 달라지는데요. 낑낑거리는 이유 4가지와 그 상황에 대해서 알아보도록 해요. 이유 1. 원하는 게 있다멍 강아지는 원하는 게 있을 때 낑낑 소리를 내며 의사 표현을 하곤 해요. 종종 강아지가 간식을 먹고 싶을 때,장난감이 소파 밑으로 들어갔을 때와 같은 상황에 낑낑거릴 때가 있죠. 이처럼 스스로 해결할 수 없는 일이 생겼을 때 낑낑 소리를 내며 보호자에게 도움을 요청하게 돼요. 또한, 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수
# 🔢 3 | 🐶 초코 | ❓질문: 다른 강아지와 놀다가 갑자기 낑낑거려요. 왜 그런건가요... | 🕒 응답시간: 23.686s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 발을 만지려고 하면 극도로 싫어하고 물려고 해요. 왜 ... | 🕒 응답시간: 19.545s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 3 | 🐶 초코 | ❓질문: 가족 중 특정한 사람만 따라다니고, 다른 사람은 피해요... | 🕒 응답시간: 20.001s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 산책 나가면 갑자기 한 방향으로만 끌고 가려 해요. 이... | 🕒 응답시간: 18.991s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 요즘 자꾸 자기 엉덩이 주변을 핥아요. 혹시 항문샘 문... | 🕒 응답시간: 16.67s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 낯선 사람을 보면 너무 짖고 흥분해요. 어떻게 해야 하... | 🕒 응답시간: 15.891s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 혼자 두면 짖고 물건을 망가뜨려요. 분리불안일까요?... | 🕒 응답시간: 18.609s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  강아지의 화난 표정 및 목소리를 보고 들었을 때의 반응도 살펴 보았다. 강아지는 다른 강아지의 화난 표정을 보고, 자기 입을 핥는 행동을 보이기는 하였으나, 사람이 화난 표정을 지었을 때보다는 반응이 덜 하였다. 강아지와 인간의 교감 반려인들의 경우 강아지에게 위로를 받는다는 표현을 자주 쓴다. 우울한 상태로 집에 있으면, 강아지가 옆에와서 위로해주는 듯한 묘한 기분이 들고는 하다. 실제로 강아지들은 우리가 생각하는 것보다 우리의 감정을 잘 알고 있을 수도 있다. 강아지가 혹시 나를 볼때마다 자기 입을 핥는다면, 내 표정이 너무 어둡지는 아닌지, 생각 해볼 필요가 있어 보인다. 반려동물의 행동이 궁금하다면? 멍냥? 에 물어보세요
#
# 눈 주변으로 퍼져 더 악화될 가능성도 있기 때문입니다. 또한, 강아지가 가만히 있지 않기 때문에 다른 사고로 이어질 수도 있어요.
#
# 많진 않을 거야. 보호자들은 할 일이 많아 강아지를 혼자 두고 집을 비우는 경우가 많지. 강아지는 보호자와 떨어져 있는 시간이 길기 때문에, 보호자가 집에 있을 때 함께 시간을 보내고 싶어 해. 그래서 잠을 잘 때라도 붙어서 자려고 하는 걸 수 있어. 4. 본능적인 행동 갓 태어난 강아지는 시각, 청각이 완전하지 않은 상태라 보거나 들을 수 없어. 또, 제대로 움직일 수도 없지. 이때 외부의 천적에게 노출되면 아주 위험해지기 때문에 엄마 강아지는 땅에 굴을 파 그 속에서 새끼 강아지들을 보호해. 그래서 강아지는 본능적으로 굴과 비슷한 환경에서 편안함을 느껴. 이불 속 역시 굴처럼 주변이 막혀있는 아늑한 환경이기 때문에 강아지들은 이불 속에서 안정감을 느끼게 돼. 그래서 불안하거나 스트레스를 받는 상황에 이불 속으로 들어가려는 행동을 보일 수 있어. 강아지가 이불 속 들어가면 답답하지 않을까? 강아지가 이불 속에 들어가 있다면 덥고 숨쉬기 힘들 거라고 생각할 수 있어. 질식하지 않을까 걱정될 수도 있고.
# 🔢 4 | 🐶 몽이 | ❓질문: 밖에서 다른 강아지들만 보면 공격적으로 굴어요. 왜 그... | 🕒 응답시간: 21.852s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 산책 도중 자꾸 땅을 파요. 무슨 의미일까요?... | 🕒 응답시간: 17.825s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 요즘 문만 열면 밖으로 도망가려고 해요. 왜 그럴까요?... | 🕒 응답시간: 18.198s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 평소엔 얌전한데, 갑자기 소파 밑에 숨어서 안 나오려고... | 🕒 응답시간: 18.449s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  같은 증상을 보이는데요. 만성 염증으로 이어질 수 있으니 동물 병원에서 꼭 치료해 주도록 합시다 <강아지 중이염 증상> 머리를 심하게 흔든다 머리, 귀 주변 만지는 걸 싫어한다 머리를 한쪽으로 심하게 기울인다 귀에서 냄새가 남 귀에서 진물이 나온다 5. 소리 듣는 중 강아지 귀 겉 부분는 소리를 모으는 역할을 해요. 그래서 강아지는 소리에 집중할 때 귀를 뒤로 젖히기도 합니다. 산책하다가 가만히 서서 귀를 뒤로 젖힌다면, 들려오는 소리를 열심히 듣고 있는 걸 수 있겠죠 ㅎㅎ 6. 애인구함 귀를 뒤로 젖히는 건 관심이 있음을 나타내는 행동 언어이기도 해요. 특히, 수컷 강아지가 암컷 강아지에게 구애를 할 때 이런 행동을 보일 수 있습니다. 강아지는 어떻게 귀를 움직일까? 강아지 귀에는 18개 이상의 근육이 있어요. 그래서 사람과 달리 귀를 앞, 뒤, 옆, 아래로 움직일 수 있고, 각 귀를 독립적으로 움직일 수도 있다고 합니다.
#
# 재미있게 놀 때 강아지의 귀는 앞으로 쫑긋하고 있으며, 입은 벌리고 있다. 혹은 주인이 알아듣지 못 하는 말을 할 때도 귀를 쫑긋하며 고개를 갸우뚱 한다. 이 외에도, 외부로부터 알지 못 하는 어떤 소리를 들었을 때 귀를 세우고 그 소리가 무엇인지 파악하려고 한다. 이 때는, 몸을 앞으로 쭉 빼고 꼬리를 꼿꼿하게 위로 올리는 것이 특징이다. 귀가 앞뒤로 왔다갔다 움직임 강아지는 걱정이 되거나 무엇인가를 결정해야 할 때 귀를 앞뒤로 왔다갔다 움직인다. 예를 들어, 강아지를 친구 집에 맡기려고 데려가는 등 익숙하지 않은 상황에 처하게 되면 귀가 바쁘게 움직이는 것을 볼 수 있다. 이것은 현재의 상황이 무엇인지 알지 못 해 혼란스러울 때 나타나는 신호다. 뒤로 쳐진 귀 귀가 뒤로 쳐지는 것은 행복감 혹은 두려움을 의미한다. 이 행동은 특히, 사람 혹은 다른 동물과 함께 있을 때 두드러지게 나타난다. 먼저, 귀를 뒤로 한껏 젖히고 입을 벌리고 있다면 현재 행복한 상태에 있다는 의미다. 반면에, 강아지가
#
# 근육이 붙어있고, 피부는 털로 덮여져 있다. 그렇기 때문에 귓바퀴가 짧은 견종은 보통 귀가 서게 되고, 귓바퀴가 길어서 귀가 상대적으로 무거운 견종은 쳐진 귀의 형태가 유지된다. 귀가 서는 견종인데도 쳐져있는 이유 귀가 서는 견종인 경우 성장기에 귀가 서게 된다. 각 강아지마다 다르기 때문에 일반화 하기는 어렵지만 보통 6주에서 길게는 수 개월까지도 걸리는 것으로 알려져 있다. 또한, 귀가 섰다가 다시 쳐지거나 한 쪽만 서게 되는 경우도 많이 있다. 귀거 서지 않거나, 한 쪽만 스거나, 다른 강아지들보다 늦게 서는 이유는 아래 정도로 좁혀진다. 유전적 및 성장단계 관련 요인과 관련하여서는 주인이 해줄 수 있는 것이 없으나 환경적 요인의 경우 주인이 체크를 해줄 수 있다. 유전적 요인 귓바퀴가 일반적인 크기보다 크거나 무거운 경우 귀가 부드럽고 가벼워서 귀의 끝부분 혹은 중간부분이 접히는 경우 양쪽 귀 사이의 공간이 넓은 경우 환경적 요인 귀를 과도하게 만진 경우 혹은 지속적으로 넘겨준 경우 모견이나
# 🔢 4 | 🐶 몽이 | ❓질문: 요즘 자꾸 귀를 긁고 머리를 흔들어요. 귀에 문제가 있... | 🕒 응답시간: 12.634s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 코가 평소보다 말라 있고, 따뜻해요. 열이 있는 건가요... | 🕒 응답시간: 16.241s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  살짝 따뜻한 정도로 유지되어야 합니다. 또한 손으로 톡톡 만졌을 때 갈라짐이 없고 탄력이 있어야 건강한 발바닥이에요. 발바닥 틈새에 작은 이물질이 끼어 있지 않은지도 주기적으로 체크해 주시면 좋습니다.
#
# 하지만 발바닥 털이 길거나 습기가 차면 오히려 과열될 수 있어 관리가 필요합니다. 강아지 발바닥의 주요 역할 충격 흡수: 관절 보호 및 안정적인 걸음걸이 유지체온 조절: 땀샘을 통해 열을 방출미끄러짐 방지: 안정적인 보행 지원외부 보호: 바닥의 거친 환경으로부터 발을 보호 강아지 발바닥 건강을 위한 관리법 5가지 1 발바닥 털 관리 발바닥 털이 길면이물질이 끼거나 미끄러질 위험이 있습니다. 특히, 습기가 차면세균 번식이 증가할 수 있으므로 주기적으로 다듬어 주세요.이발기 또는 가위 사용여름철에는 털을 더 짧게 유지해 체온 조절 도움 2 발바닥 패드 상태 체크 강아지 발바닥 패드는 예상보다 약해 쉽게벗겨지거나 갈라질 수있습니다. 발바닥에 상처나 갈라짐이 없는지정기적으로 확인 절뚝거리거나 걷기를 꺼린다면발바닥 문제일 가능성 3발바닥 습진예방 강아지가발을 자주 핥거나 붉어지는 증상이 있다면 습진을 의심해볼 수 있습니다. 목욕 후발바닥을 완전히 건조알레르기 원인 파악 후 관리 필요 시동물병원에서 처방받은 연고
#
# 털을 자를 수 있다. 발바닥 털을 잘랐는데도 자꾸 미끄러진다면, 미끄러운 실내 바닥이 원인일 수 있다. 강아지가 바닥에서 미끄러지지 않도록 바닥에 미끄럼 방지 매트를 깔아주면 효과를 볼 수 있다. 2. 여름철, 체온 조절에 도움이 된다 발바닥은 땀샘이 있는 부위로 체온 조절에도 중요한 역할을 한다. 따라서, 여름철에는 발바닥 털을 짧게 밀어주는 게 좋다. 3. 겨울철, 눈과 제설제가 덜 붙는다 발바닥 털이 길면 겨울철 산책 시 눈과 제설제가 뭉치게 될 수 있다. 이런 경우 발바닥 화상, 벗겨짐, 상처 등이 생길 수 있기 때문에 발바닥 털을 짧게 잘라주는 게 좋다. 또한, 산책 후에는 발을 꼼꼼히 씻겨주는 게 중요하다. 혹은 강아지에게 신발을 신기고 산책하는 것도 방법이다. 발바닥 패드 확인하기 강아지 발바닥 패드는 생각보다 약하기 때문에, 다양한 원인으로 인해상처가 나거나 벗겨질 수 있다.특히, 어린 강아지는 발바닥 패드가 더욱 약해 주의가 필요하다. 강아지 발바닥 벗겨졌을 때 증상 절뚝거린다 한 발로
# 🔢 4 | 🐶 몽이 | ❓질문: 요즘 발바닥을 자꾸 핥아요. 발에 이상 있는 걸까요?... | 🕒 응답시간: 14.094s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  상처가 생겨 충혈된 경우 아래와 같은 증상을 보일 수 있어요. 눈에 움푹 파인 듯한 상처 자국 눈을 가늘게 뜸 눈물량이 늘어남 밝은 빛을 보는 걸 피함 눈병이 생겼어요 강아지에게 눈병이 생겼을 때에도 충혈이 될 수 있어요. 강아지 눈의 흰자 겉 부분과 눈꺼풀 안쪽의 붉은 살을 결막이라고 하는데요. 한쪽 눈 혹은 양쪽 눈의 결막에 염증이 생긴 걸 결막염이라고 해요. 결막염이 생기는 원인은 알레르기, 외상, 다른 질환 등 다양합니다. 결막염으로 인한 충혈이 의심된다면 아래와 같은 증상이 있는지 확인해 보세요. 노란색 눈곱 눈을 과하게 깜빡임 눈을 잘 뜨지 못함 눈을 자꾸 비빔 녹내장은 눈의 안압이 올라가서 시신경이 눌려 손상되는 질병이에요. 시신경이 손상되면 시력이 떨어지게 되는데, 떨어진 시력은 다시 되돌릴 수 없습니다. 안압이 올라가는 이유는 눈 속 액체인 안방수가 제대로 배출되지 않는 게 원인으로 알려져 있습니다. 안방수: 각막과 수정체 사이를 채운 액체로, 눈에 영양을 공급하고 안압을 유지하는
#
# 반려견이 자꾸 눈을 비빈다면원인은 따로 있다 - 눈에 무언가가 들어갔거나 눈이 간지러울 때면 눈을 비비거나 긁게 된다. 눈을 계속 비비게 되면 눈이 충혈되고 통증도 찾아온다. 이는 사람뿐 아니라 반려견도 마찬가지다. 다만 사람은 증상을 정확히 말로 표현하며, 안과에서 치료를 받거나 안약을 처방받을 수 있지만 반려견은 말을 하지 못하기 때문에 계속 눈을 긁게 되어 각막에 상처를 입는 경우가 많다. 증상이 심각해지면 각막에 궤양이 생기기도 한다. 강아지 각막궤양의 원인과 증상에 대해 알아본다. 눈 크고 튀어나와 있는 품종은 특히 각막궤양에 취약 각막은 눈의 가장 바깥쪽 표면에 있는 얇고 투명한 막이다. 여러 겹의 층으로 이루어져 바깥부터 상피·기질·데스메막·내피로 구성돼 있다. 빛을 안구 내부로 전달함과 동시에 눈 안의 구조물을 둘러싸는 역할을 하고 있다. 각막궤양은 각막이 찢기거나 탈락된 상태를 말한다. 즉, 눈 표면에 흠집이 나는 외상이다. 각막 두께는 매우 얇아서 상처 깊이에 따라 심각성이 달라진다.
# 🔢 4 | 🐶 몽이 | ❓질문: 왼쪽 눈만 자꾸 깜빡여요. 결막염 같은 걸까요?... | 🕒 응답시간: 14.548s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 배변을 자주 해요. 하루에 5번은 넘는 것 같은데 정상... | 🕒 응답시간: 16.59s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 갑자기 피부에 붉은 반점이 생겼어요. 알레르기일까요?... | 🕒 응답시간: 15.322s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  쉬운 겨드랑이, 가슴, 귀 뒤 등은 더 세심하게 빗어주는 것이 좋다. 빗질 중 뭉친 털을 발견했다면, 뭉친 털을 잡고 반려견의 몸 바깥 방향으로 살살 빗으며 풀어주면 된다. 엉킨 털이 잘 풀리지 않는다면 가위로 잘라주는 것도 방법이다. 참고로, 건조한 가을철에 목욕을 너무 자주 하면 반려견의 털과 피부를 더욱 건조하게 만들 수 있으므로 주의해야 한다. 옷을 너무 오래 입혀 놓는 습관은 피부에 공기가 잘 통하지 않을 수 있어 피해야 한다. 이때는 탈모 의심하고 병원 가야 만일 털갈이로 털이 빠진 부위에 털이 다시 나지 않고 피부가 드러나 보인다면 탈모를 의심해봐야 한다. 아울러, 피부가 거칠어지거나 털이 빠진 부위를 수시로 긁거나 핥는 증상, 털이 윤기를 잃고 버석거리는 증상 등이 동반된다면 질환에 의해 탈모가 생긴 상태일 가능성이 높다. 반려견 탈모는 다양한 원인에 의해 생길 수 있는데, 털이 대칭적으로 빠지거나 얇아진다면 갑상선 기능 저하증, 부신피질 기능항진증 등을 의심해 볼 수 있다. 부분적으로
# 🔢 4 | 🐶 몽이 | ❓질문: 몸을 자꾸 긁고 털이 빠져요. 피부병일 가능성도 있나요... | 🕒 응답시간: 19.033s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  강아지가 사료를 안먹어요 해결책 - 평소에 사료를 잘 먹던 강아지가 사료를 안 먹으면 걱정이 앞선다. 어디 아픈 것은 아닌지 혹은 내가 사준 사료가 입맛에 맞지는 않는지 등 다양한 생각들이 머리를 스쳐 지나간다. 내 강아지는 왜 사료를 안먹고 있는걸까? 1. 너무 많은 간식 사람 음식을 주었을 때 대부분의 경우가 이에 해당한다. 강아지에게 사료는 가장 맛없는 음식 이라는 말이 있다. 강아지가 너무 귀엽다고, 간식을 계속 주거나, 요리 중에 사람 음식을 계속 주다보면, 반려견은 사료 외 음식들의 맛을 알아가 사료를 거부한다. 가끔, 난 정말 사료만 주는데 강아지가 사료를 거부한다라는 반려인들이 있다. 이런 경우 가족 구성원 중 누군가 지속적으로 사료 외 다른 음식들을 과도하게 주고 있지 않는지 합리적인 의심해봐야 한다. 해결책 1 : 사료 외 다른 음식 급여 중단 반려인으로서 마음이 아프지만, 사료 외 다른 음식의 급여를 중단 하는 수 밖에 없다. 강아지가 요리 중에 측은한 눈빛으로 바라보더라도, 외면할
# 🔢 4 | 🐶 몽이 | ❓질문: 밥을 잘 안 먹고 사료를 입에 넣었다 뱉어요. 입 안에... | 🕒 응답시간: 25.32s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 밤마다 짖고 깨서 잠을 잘 못 자요. 불면증 같은 게 ... | 🕒 응답시간: 18.854s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 식사 후 구토를 자주 해요. 위장이 약한 걸까요?... | 🕒 응답시간: 13.349s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 물을 거의 안 마셔요. 탈수 걱정해도 될까요?... | 🕒 응답시간: 17.251s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 밥을 잘 안 먹어요. 입맛이 없는 걸까요? 편식일까요?... | 🕒 응답시간: 15.311s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 잠자는 시간이 너무 많아졌어요. 왜 그럴까요?... | 🕒 응답시간: 14.799s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 앉아, 기다려 같은 기본 훈련을 잘 안들어요.... | 🕒 응답시간: 14.94s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 하네스를 차려고 하면 도망가요. 외출이 싫은 걸까요?... | 🕒 응답시간: 28.937s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 차를 타면 자꾸 구토해요. 어떻게 훈련하면 좋을까요?... | 🕒 응답시간: 20.532s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 목줄만 보면 도망가요. 산책을 싫어하는 걸까요?... | 🕒 응답시간: 17.957s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 산책 중에 자꾸 바닥에 있는 걸 주워 먹어요. 위험하지... | 🕒 응답시간: 18.005s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 계단 오르내릴 때 다리를 절어요. 관절 문제일 수 있나... | 🕒 응답시간: 14.503s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ 이유 4. 반갑다멍 강아지는 너무 반가울 때도 낑낑거려요. 몽이는 초인종 소리가 들리면 그때부터 낑낑거리면서 꼬리를 흔들고 좋아해요. 가족들이 외출했다 들어왔을 때도 낑~ 하는 소리를 내곤 합니다 ㅎㅎ 이때, 강아지가 너무 흥분해서 소변을 흘릴 수도 있어요. 흥분으로 인한 소변 실수는 보통 아직 덜 성숙한 어린 강아지가 종종 하는 행동이에요. 이런 행동은 시간이 지나면서 점점 나아지게 된답니다. 하지만, 다 큰 강아지가 계속해서소변 실수를 한다면, 흥분을 가라앉힐 수 있도록 무시하는 등 훈련을 통해 고쳐주는 게 좋습니다.
#
# 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수 있어요. 제가 반려하고 있는 몽이의 경우 산책에 가고 싶을 때 현관 앞에서 낑낑거린답니다 ㅎㅎ 이유 2. 불안하다멍 강아지는 불안하거나 두려운 상황에서도 낑낑거리는 소리를 내곤 하는데요. 낯선 곳에 가거나 새로운 사람을 만났을 때 겁을 먹으면 이런 행동을 할 수 있습니다. 무섭고 불안하다는 의미에서 낑낑 소리를 내는 거죠. 또한, 보호자가 집을 나설 때 낑낑거릴 수 있어요. 이런 경우분리불안이 있다는 의미일 수 있습니다. 만약 분리불안으로 인한 다른 행동이 함께 보이는지 확인해보고, 맞다면 이를 해결할 수 있도록 노력해야 해요. 이유 3. 아프다멍 강아지는 아플 때도 낑낑 소리를 낼 수 있어요. 예를 들어, 갑자기 계단이나 소파를 오를 때 낑낑거린다면 관절이 약해졌다는 의미일 수 있어요. 아픈 경우강아지의 움직임이 줄어들고 기운도 없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ
#
# 강아지 낑낑 소리 속 숨겨진 의미는? - 강아지 낑낑, 끙끙 소리는 흔히 들을 수 있는 소리예요. 이런 낑낑 소리 속에는 다양한 의미가 있는데요. 강아지가 어떤 걸 말하려고 하는지 쉽게 알 수 있을 때도 있지만, 그렇지 않은 경우도 있어요. 어떤 이유가 있는지 정확히 알아보도록 해요. 강아지가 낑낑거리는 이유는? 강아지 낑낑 소리, 상황에 따라 달라 강아지 낑낑 소리에는 다양한 의미가 있어요. 같은 낑낑 소리여도, 그 의미는 상황에 따라 달라지는데요. 낑낑거리는 이유 4가지와 그 상황에 대해서 알아보도록 해요. 이유 1. 원하는 게 있다멍 강아지는 원하는 게 있을 때 낑낑 소리를 내며 의사 표현을 하곤 해요. 종종 강아지가 간식을 먹고 싶을 때,장난감이 소파 밑으로 들어갔을 때와 같은 상황에 낑낑거릴 때가 있죠. 이처럼 스스로 해결할 수 없는 일이 생겼을 때 낑낑 소리를 내며 보호자에게 도움을 요청하게 돼요. 또한, 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수
# 🔢 4 | 🐶 몽이 | ❓질문: 다른 강아지와 놀다가 갑자기 낑낑거려요. 왜 그런건가요... | 🕒 응답시간: 19.027s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 발을 만지려고 하면 극도로 싫어하고 물려고 해요. 왜 ... | 🕒 응답시간: 22.379s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 4 | 🐶 몽이 | ❓질문: 가족 중 특정한 사람만 따라다니고, 다른 사람은 피해요... | 🕒 응답시간: 20.637s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 5 | 🐶 루루 | ❓질문: 산책 나가면 갑자기 한 방향으로만 끌고 가려 해요. 이... | 🕒 응답시간: 18.35s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 5 | 🐶 루루 | ❓질문: 요즘 자꾸 자기 엉덩이 주변을 핥아요. 혹시 항문샘 문... | 🕒 응답시간: 18.712s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 5 | 🐶 루루 | ❓질문: 낯선 사람을 보면 너무 짖고 흥분해요. 어떻게 해야 하... | 🕒 응답시간: 22.454s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 5 | 🐶 루루 | ❓질문: 혼자 두면 짖고 물건을 망가뜨려요. 분리불안일까요?... | 🕒 응답시간: 21.618s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  강아지의 화난 표정 및 목소리를 보고 들었을 때의 반응도 살펴 보았다. 강아지는 다른 강아지의 화난 표정을 보고, 자기 입을 핥는 행동을 보이기는 하였으나, 사람이 화난 표정을 지었을 때보다는 반응이 덜 하였다. 강아지와 인간의 교감 반려인들의 경우 강아지에게 위로를 받는다는 표현을 자주 쓴다. 우울한 상태로 집에 있으면, 강아지가 옆에와서 위로해주는 듯한 묘한 기분이 들고는 하다. 실제로 강아지들은 우리가 생각하는 것보다 우리의 감정을 잘 알고 있을 수도 있다. 강아지가 혹시 나를 볼때마다 자기 입을 핥는다면, 내 표정이 너무 어둡지는 아닌지, 생각 해볼 필요가 있어 보인다. 반려동물의 행동이 궁금하다면? 멍냥? 에 물어보세요
#
# 눈 주변으로 퍼져 더 악화될 가능성도 있기 때문입니다. 또한, 강아지가 가만히 있지 않기 때문에 다른 사고로 이어질 수도 있어요.
#
# ...
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 몸을 자꾸 긁고 털이 빠져요. 피부병일 가능성도 있나요... | 🕒 응답시간: 13.116s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  강아지가 사료를 안먹어요 해결책 - 평소에 사료를 잘 먹던 강아지가 사료를 안 먹으면 걱정이 앞선다. 어디 아픈 것은 아닌지 혹은 내가 사준 사료가 입맛에 맞지는 않는지 등 다양한 생각들이 머리를 스쳐 지나간다. 내 강아지는 왜 사료를 안먹고 있는걸까? 1. 너무 많은 간식 사람 음식을 주었을 때 대부분의 경우가 이에 해당한다. 강아지에게 사료는 가장 맛없는 음식 이라는 말이 있다. 강아지가 너무 귀엽다고, 간식을 계속 주거나, 요리 중에 사람 음식을 계속 주다보면, 반려견은 사료 외 음식들의 맛을 알아가 사료를 거부한다. 가끔, 난 정말 사료만 주는데 강아지가 사료를 거부한다라는 반려인들이 있다. 이런 경우 가족 구성원 중 누군가 지속적으로 사료 외 다른 음식들을 과도하게 주고 있지 않는지 합리적인 의심해봐야 한다. 해결책 1 : 사료 외 다른 음식 급여 중단 반려인으로서 마음이 아프지만, 사료 외 다른 음식의 급여를 중단 하는 수 밖에 없다. 강아지가 요리 중에 측은한 눈빛으로 바라보더라도, 외면할
# 🔢 9 | 🐶 별이 | ❓질문: 밥을 잘 안 먹고 사료를 입에 넣었다 뱉어요. 입 안에... | 🕒 응답시간: 13.964s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 밤마다 짖고 깨서 잠을 잘 못 자요. 불면증 같은 게 ... | 🕒 응답시간: 32.521s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 식사 후 구토를 자주 해요. 위장이 약한 걸까요?... | 🕒 응답시간: 13.971s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 물을 거의 안 마셔요. 탈수 걱정해도 될까요?... | 🕒 응답시간: 16.712s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 밥을 잘 안 먹어요. 입맛이 없는 걸까요? 편식일까요?... | 🕒 응답시간: 15.456s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 잠자는 시간이 너무 많아졌어요. 왜 그럴까요?... | 🕒 응답시간: 17.486s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 앉아, 기다려 같은 기본 훈련을 잘 안들어요.... | 🕒 응답시간: 14.924s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 하네스를 차려고 하면 도망가요. 외출이 싫은 걸까요?... | 🕒 응답시간: 17.985s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 차를 타면 자꾸 구토해요. 어떻게 훈련하면 좋을까요?... | 🕒 응답시간: 16.913s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 목줄만 보면 도망가요. 산책을 싫어하는 걸까요?... | 🕒 응답시간: 13.72s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 산책 중에 자꾸 바닥에 있는 걸 주워 먹어요. 위험하지... | 🕒 응답시간: 19.783s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 계단 오르내릴 때 다리를 절어요. 관절 문제일 수 있나... | 🕒 응답시간: 13.398s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ 이유 4. 반갑다멍 강아지는 너무 반가울 때도 낑낑거려요. 몽이는 초인종 소리가 들리면 그때부터 낑낑거리면서 꼬리를 흔들고 좋아해요. 가족들이 외출했다 들어왔을 때도 낑~ 하는 소리를 내곤 합니다 ㅎㅎ 이때, 강아지가 너무 흥분해서 소변을 흘릴 수도 있어요. 흥분으로 인한 소변 실수는 보통 아직 덜 성숙한 어린 강아지가 종종 하는 행동이에요. 이런 행동은 시간이 지나면서 점점 나아지게 된답니다. 하지만, 다 큰 강아지가 계속해서소변 실수를 한다면, 흥분을 가라앉힐 수 있도록 무시하는 등 훈련을 통해 고쳐주는 게 좋습니다.
#
# 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수 있어요. 제가 반려하고 있는 몽이의 경우 산책에 가고 싶을 때 현관 앞에서 낑낑거린답니다 ㅎㅎ 이유 2. 불안하다멍 강아지는 불안하거나 두려운 상황에서도 낑낑거리는 소리를 내곤 하는데요. 낯선 곳에 가거나 새로운 사람을 만났을 때 겁을 먹으면 이런 행동을 할 수 있습니다. 무섭고 불안하다는 의미에서 낑낑 소리를 내는 거죠. 또한, 보호자가 집을 나설 때 낑낑거릴 수 있어요. 이런 경우분리불안이 있다는 의미일 수 있습니다. 만약 분리불안으로 인한 다른 행동이 함께 보이는지 확인해보고, 맞다면 이를 해결할 수 있도록 노력해야 해요. 이유 3. 아프다멍 강아지는 아플 때도 낑낑 소리를 낼 수 있어요. 예를 들어, 갑자기 계단이나 소파를 오를 때 낑낑거린다면 관절이 약해졌다는 의미일 수 있어요. 아픈 경우강아지의 움직임이 줄어들고 기운도 없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ
#
# 강아지 낑낑 소리 속 숨겨진 의미는? - 강아지 낑낑, 끙끙 소리는 흔히 들을 수 있는 소리예요. 이런 낑낑 소리 속에는 다양한 의미가 있는데요. 강아지가 어떤 걸 말하려고 하는지 쉽게 알 수 있을 때도 있지만, 그렇지 않은 경우도 있어요. 어떤 이유가 있는지 정확히 알아보도록 해요. 강아지가 낑낑거리는 이유는? 강아지 낑낑 소리, 상황에 따라 달라 강아지 낑낑 소리에는 다양한 의미가 있어요. 같은 낑낑 소리여도, 그 의미는 상황에 따라 달라지는데요. 낑낑거리는 이유 4가지와 그 상황에 대해서 알아보도록 해요. 이유 1. 원하는 게 있다멍 강아지는 원하는 게 있을 때 낑낑 소리를 내며 의사 표현을 하곤 해요. 종종 강아지가 간식을 먹고 싶을 때,장난감이 소파 밑으로 들어갔을 때와 같은 상황에 낑낑거릴 때가 있죠. 이처럼 스스로 해결할 수 없는 일이 생겼을 때 낑낑 소리를 내며 보호자에게 도움을 요청하게 돼요. 또한, 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수
# 🔢 9 | 🐶 별이 | ❓질문: 다른 강아지와 놀다가 갑자기 낑낑거려요. 왜 그런건가요... | 🕒 응답시간: 23.134s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 발을 만지려고 하면 극도로 싫어하고 물려고 해요. 왜 ... | 🕒 응답시간: 19.419s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 9 | 🐶 별이 | ❓질문: 가족 중 특정한 사람만 따라다니고, 다른 사람은 피해요... | 🕒 응답시간: 15.601s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 산책 나가면 갑자기 한 방향으로만 끌고 가려 해요. 이... | 🕒 응답시간: 16.481s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 요즘 자꾸 자기 엉덩이 주변을 핥아요. 혹시 항문샘 문... | 🕒 응답시간: 20.365s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 낯선 사람을 보면 너무 짖고 흥분해요. 어떻게 해야 하... | 🕒 응답시간: 15.946s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 혼자 두면 짖고 물건을 망가뜨려요. 분리불안일까요?... | 🕒 응답시간: 16.806s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  강아지의 화난 표정 및 목소리를 보고 들었을 때의 반응도 살펴 보았다. 강아지는 다른 강아지의 화난 표정을 보고, 자기 입을 핥는 행동을 보이기는 하였으나, 사람이 화난 표정을 지었을 때보다는 반응이 덜 하였다. 강아지와 인간의 교감 반려인들의 경우 강아지에게 위로를 받는다는 표현을 자주 쓴다. 우울한 상태로 집에 있으면, 강아지가 옆에와서 위로해주는 듯한 묘한 기분이 들고는 하다. 실제로 강아지들은 우리가 생각하는 것보다 우리의 감정을 잘 알고 있을 수도 있다. 강아지가 혹시 나를 볼때마다 자기 입을 핥는다면, 내 표정이 너무 어둡지는 아닌지, 생각 해볼 필요가 있어 보인다. 반려동물의 행동이 궁금하다면? 멍냥? 에 물어보세요
#
# 눈 주변으로 퍼져 더 악화될 가능성도 있기 때문입니다. 또한, 강아지가 가만히 있지 않기 때문에 다른 사고로 이어질 수도 있어요.
#
# 많진 않을 거야. 보호자들은 할 일이 많아 강아지를 혼자 두고 집을 비우는 경우가 많지. 강아지는 보호자와 떨어져 있는 시간이 길기 때문에, 보호자가 집에 있을 때 함께 시간을 보내고 싶어 해. 그래서 잠을 잘 때라도 붙어서 자려고 하는 걸 수 있어. 4. 본능적인 행동 갓 태어난 강아지는 시각, 청각이 완전하지 않은 상태라 보거나 들을 수 없어. 또, 제대로 움직일 수도 없지. 이때 외부의 천적에게 노출되면 아주 위험해지기 때문에 엄마 강아지는 땅에 굴을 파 그 속에서 새끼 강아지들을 보호해. 그래서 강아지는 본능적으로 굴과 비슷한 환경에서 편안함을 느껴. 이불 속 역시 굴처럼 주변이 막혀있는 아늑한 환경이기 때문에 강아지들은 이불 속에서 안정감을 느끼게 돼. 그래서 불안하거나 스트레스를 받는 상황에 이불 속으로 들어가려는 행동을 보일 수 있어. 강아지가 이불 속 들어가면 답답하지 않을까? 강아지가 이불 속에 들어가 있다면 덥고 숨쉬기 힘들 거라고 생각할 수 있어. 질식하지 않을까 걱정될 수도 있고.
# 🔢 10 | 🐶 쫑이 | ❓질문: 밖에서 다른 강아지들만 보면 공격적으로 굴어요. 왜 그... | 🕒 응답시간: 23.807s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 산책 도중 자꾸 땅을 파요. 무슨 의미일까요?... | 🕒 응답시간: 20.023s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 요즘 문만 열면 밖으로 도망가려고 해요. 왜 그럴까요?... | 🕒 응답시간: 16.87s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 평소엔 얌전한데, 갑자기 소파 밑에 숨어서 안 나오려고... | 🕒 응답시간: 19.197s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  같은 증상을 보이는데요. 만성 염증으로 이어질 수 있으니 동물 병원에서 꼭 치료해 주도록 합시다 <강아지 중이염 증상> 머리를 심하게 흔든다 머리, 귀 주변 만지는 걸 싫어한다 머리를 한쪽으로 심하게 기울인다 귀에서 냄새가 남 귀에서 진물이 나온다 5. 소리 듣는 중 강아지 귀 겉 부분는 소리를 모으는 역할을 해요. 그래서 강아지는 소리에 집중할 때 귀를 뒤로 젖히기도 합니다. 산책하다가 가만히 서서 귀를 뒤로 젖힌다면, 들려오는 소리를 열심히 듣고 있는 걸 수 있겠죠 ㅎㅎ 6. 애인구함 귀를 뒤로 젖히는 건 관심이 있음을 나타내는 행동 언어이기도 해요. 특히, 수컷 강아지가 암컷 강아지에게 구애를 할 때 이런 행동을 보일 수 있습니다. 강아지는 어떻게 귀를 움직일까? 강아지 귀에는 18개 이상의 근육이 있어요. 그래서 사람과 달리 귀를 앞, 뒤, 옆, 아래로 움직일 수 있고, 각 귀를 독립적으로 움직일 수도 있다고 합니다.
#
# 재미있게 놀 때 강아지의 귀는 앞으로 쫑긋하고 있으며, 입은 벌리고 있다. 혹은 주인이 알아듣지 못 하는 말을 할 때도 귀를 쫑긋하며 고개를 갸우뚱 한다. 이 외에도, 외부로부터 알지 못 하는 어떤 소리를 들었을 때 귀를 세우고 그 소리가 무엇인지 파악하려고 한다. 이 때는, 몸을 앞으로 쭉 빼고 꼬리를 꼿꼿하게 위로 올리는 것이 특징이다. 귀가 앞뒤로 왔다갔다 움직임 강아지는 걱정이 되거나 무엇인가를 결정해야 할 때 귀를 앞뒤로 왔다갔다 움직인다. 예를 들어, 강아지를 친구 집에 맡기려고 데려가는 등 익숙하지 않은 상황에 처하게 되면 귀가 바쁘게 움직이는 것을 볼 수 있다. 이것은 현재의 상황이 무엇인지 알지 못 해 혼란스러울 때 나타나는 신호다. 뒤로 쳐진 귀 귀가 뒤로 쳐지는 것은 행복감 혹은 두려움을 의미한다. 이 행동은 특히, 사람 혹은 다른 동물과 함께 있을 때 두드러지게 나타난다. 먼저, 귀를 뒤로 한껏 젖히고 입을 벌리고 있다면 현재 행복한 상태에 있다는 의미다. 반면에, 강아지가
#
# 근육이 붙어있고, 피부는 털로 덮여져 있다. 그렇기 때문에 귓바퀴가 짧은 견종은 보통 귀가 서게 되고, 귓바퀴가 길어서 귀가 상대적으로 무거운 견종은 쳐진 귀의 형태가 유지된다. 귀가 서는 견종인데도 쳐져있는 이유 귀가 서는 견종인 경우 성장기에 귀가 서게 된다. 각 강아지마다 다르기 때문에 일반화 하기는 어렵지만 보통 6주에서 길게는 수 개월까지도 걸리는 것으로 알려져 있다. 또한, 귀가 섰다가 다시 쳐지거나 한 쪽만 서게 되는 경우도 많이 있다. 귀거 서지 않거나, 한 쪽만 스거나, 다른 강아지들보다 늦게 서는 이유는 아래 정도로 좁혀진다. 유전적 및 성장단계 관련 요인과 관련하여서는 주인이 해줄 수 있는 것이 없으나 환경적 요인의 경우 주인이 체크를 해줄 수 있다. 유전적 요인 귓바퀴가 일반적인 크기보다 크거나 무거운 경우 귀가 부드럽고 가벼워서 귀의 끝부분 혹은 중간부분이 접히는 경우 양쪽 귀 사이의 공간이 넓은 경우 환경적 요인 귀를 과도하게 만진 경우 혹은 지속적으로 넘겨준 경우 모견이나
# 🔢 10 | 🐶 쫑이 | ❓질문: 요즘 자꾸 귀를 긁고 머리를 흔들어요. 귀에 문제가 있... | 🕒 응답시간: 19.031s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 코가 평소보다 말라 있고, 따뜻해요. 열이 있는 건가요... | 🕒 응답시간: 16.442s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  살짝 따뜻한 정도로 유지되어야 합니다. 또한 손으로 톡톡 만졌을 때 갈라짐이 없고 탄력이 있어야 건강한 발바닥이에요. 발바닥 틈새에 작은 이물질이 끼어 있지 않은지도 주기적으로 체크해 주시면 좋습니다.
#
# 하지만 발바닥 털이 길거나 습기가 차면 오히려 과열될 수 있어 관리가 필요합니다. 강아지 발바닥의 주요 역할 충격 흡수: 관절 보호 및 안정적인 걸음걸이 유지체온 조절: 땀샘을 통해 열을 방출미끄러짐 방지: 안정적인 보행 지원외부 보호: 바닥의 거친 환경으로부터 발을 보호 강아지 발바닥 건강을 위한 관리법 5가지 1 발바닥 털 관리 발바닥 털이 길면이물질이 끼거나 미끄러질 위험이 있습니다. 특히, 습기가 차면세균 번식이 증가할 수 있으므로 주기적으로 다듬어 주세요.이발기 또는 가위 사용여름철에는 털을 더 짧게 유지해 체온 조절 도움 2 발바닥 패드 상태 체크 강아지 발바닥 패드는 예상보다 약해 쉽게벗겨지거나 갈라질 수있습니다. 발바닥에 상처나 갈라짐이 없는지정기적으로 확인 절뚝거리거나 걷기를 꺼린다면발바닥 문제일 가능성 3발바닥 습진예방 강아지가발을 자주 핥거나 붉어지는 증상이 있다면 습진을 의심해볼 수 있습니다. 목욕 후발바닥을 완전히 건조알레르기 원인 파악 후 관리 필요 시동물병원에서 처방받은 연고
#
# 털을 자를 수 있다. 발바닥 털을 잘랐는데도 자꾸 미끄러진다면, 미끄러운 실내 바닥이 원인일 수 있다. 강아지가 바닥에서 미끄러지지 않도록 바닥에 미끄럼 방지 매트를 깔아주면 효과를 볼 수 있다. 2. 여름철, 체온 조절에 도움이 된다 발바닥은 땀샘이 있는 부위로 체온 조절에도 중요한 역할을 한다. 따라서, 여름철에는 발바닥 털을 짧게 밀어주는 게 좋다. 3. 겨울철, 눈과 제설제가 덜 붙는다 발바닥 털이 길면 겨울철 산책 시 눈과 제설제가 뭉치게 될 수 있다. 이런 경우 발바닥 화상, 벗겨짐, 상처 등이 생길 수 있기 때문에 발바닥 털을 짧게 잘라주는 게 좋다. 또한, 산책 후에는 발을 꼼꼼히 씻겨주는 게 중요하다. 혹은 강아지에게 신발을 신기고 산책하는 것도 방법이다. 발바닥 패드 확인하기 강아지 발바닥 패드는 생각보다 약하기 때문에, 다양한 원인으로 인해상처가 나거나 벗겨질 수 있다.특히, 어린 강아지는 발바닥 패드가 더욱 약해 주의가 필요하다. 강아지 발바닥 벗겨졌을 때 증상 절뚝거린다 한 발로
# 🔢 10 | 🐶 쫑이 | ❓질문: 요즘 발바닥을 자꾸 핥아요. 발에 이상 있는 걸까요?... | 🕒 응답시간: 19.592s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  상처가 생겨 충혈된 경우 아래와 같은 증상을 보일 수 있어요. 눈에 움푹 파인 듯한 상처 자국 눈을 가늘게 뜸 눈물량이 늘어남 밝은 빛을 보는 걸 피함 눈병이 생겼어요 강아지에게 눈병이 생겼을 때에도 충혈이 될 수 있어요. 강아지 눈의 흰자 겉 부분과 눈꺼풀 안쪽의 붉은 살을 결막이라고 하는데요. 한쪽 눈 혹은 양쪽 눈의 결막에 염증이 생긴 걸 결막염이라고 해요. 결막염이 생기는 원인은 알레르기, 외상, 다른 질환 등 다양합니다. 결막염으로 인한 충혈이 의심된다면 아래와 같은 증상이 있는지 확인해 보세요. 노란색 눈곱 눈을 과하게 깜빡임 눈을 잘 뜨지 못함 눈을 자꾸 비빔 녹내장은 눈의 안압이 올라가서 시신경이 눌려 손상되는 질병이에요. 시신경이 손상되면 시력이 떨어지게 되는데, 떨어진 시력은 다시 되돌릴 수 없습니다. 안압이 올라가는 이유는 눈 속 액체인 안방수가 제대로 배출되지 않는 게 원인으로 알려져 있습니다. 안방수: 각막과 수정체 사이를 채운 액체로, 눈에 영양을 공급하고 안압을 유지하는
#
# 반려견이 자꾸 눈을 비빈다면원인은 따로 있다 - 눈에 무언가가 들어갔거나 눈이 간지러울 때면 눈을 비비거나 긁게 된다. 눈을 계속 비비게 되면 눈이 충혈되고 통증도 찾아온다. 이는 사람뿐 아니라 반려견도 마찬가지다. 다만 사람은 증상을 정확히 말로 표현하며, 안과에서 치료를 받거나 안약을 처방받을 수 있지만 반려견은 말을 하지 못하기 때문에 계속 눈을 긁게 되어 각막에 상처를 입는 경우가 많다. 증상이 심각해지면 각막에 궤양이 생기기도 한다. 강아지 각막궤양의 원인과 증상에 대해 알아본다. 눈 크고 튀어나와 있는 품종은 특히 각막궤양에 취약 각막은 눈의 가장 바깥쪽 표면에 있는 얇고 투명한 막이다. 여러 겹의 층으로 이루어져 바깥부터 상피·기질·데스메막·내피로 구성돼 있다. 빛을 안구 내부로 전달함과 동시에 눈 안의 구조물을 둘러싸는 역할을 하고 있다. 각막궤양은 각막이 찢기거나 탈락된 상태를 말한다. 즉, 눈 표면에 흠집이 나는 외상이다. 각막 두께는 매우 얇아서 상처 깊이에 따라 심각성이 달라진다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 왼쪽 눈만 자꾸 깜빡여요. 결막염 같은 걸까요?... | 🕒 응답시간: 14.532s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 배변을 자주 해요. 하루에 5번은 넘는 것 같은데 정상... | 🕒 응답시간: 16.152s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 갑자기 피부에 붉은 반점이 생겼어요. 알레르기일까요?... | 🕒 응답시간: 17.537s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# 🔍 search_documents - RAG 검색된 문서:
#  쉬운 겨드랑이, 가슴, 귀 뒤 등은 더 세심하게 빗어주는 것이 좋다. 빗질 중 뭉친 털을 발견했다면, 뭉친 털을 잡고 반려견의 몸 바깥 방향으로 살살 빗으며 풀어주면 된다. 엉킨 털이 잘 풀리지 않는다면 가위로 잘라주는 것도 방법이다. 참고로, 건조한 가을철에 목욕을 너무 자주 하면 반려견의 털과 피부를 더욱 건조하게 만들 수 있으므로 주의해야 한다. 옷을 너무 오래 입혀 놓는 습관은 피부에 공기가 잘 통하지 않을 수 있어 피해야 한다. 이때는 탈모 의심하고 병원 가야 만일 털갈이로 털이 빠진 부위에 털이 다시 나지 않고 피부가 드러나 보인다면 탈모를 의심해봐야 한다. 아울러, 피부가 거칠어지거나 털이 빠진 부위를 수시로 긁거나 핥는 증상, 털이 윤기를 잃고 버석거리는 증상 등이 동반된다면 질환에 의해 탈모가 생긴 상태일 가능성이 높다. 반려견 탈모는 다양한 원인에 의해 생길 수 있는데, 털이 대칭적으로 빠지거나 얇아진다면 갑상선 기능 저하증, 부신피질 기능항진증 등을 의심해 볼 수 있다. 부분적으로
# 🔢 10 | 🐶 쫑이 | ❓질문: 몸을 자꾸 긁고 털이 빠져요. 피부병일 가능성도 있나요... | 🕒 응답시간: 18.195s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  강아지가 사료를 안먹어요 해결책 - 평소에 사료를 잘 먹던 강아지가 사료를 안 먹으면 걱정이 앞선다. 어디 아픈 것은 아닌지 혹은 내가 사준 사료가 입맛에 맞지는 않는지 등 다양한 생각들이 머리를 스쳐 지나간다. 내 강아지는 왜 사료를 안먹고 있는걸까? 1. 너무 많은 간식 사람 음식을 주었을 때 대부분의 경우가 이에 해당한다. 강아지에게 사료는 가장 맛없는 음식 이라는 말이 있다. 강아지가 너무 귀엽다고, 간식을 계속 주거나, 요리 중에 사람 음식을 계속 주다보면, 반려견은 사료 외 음식들의 맛을 알아가 사료를 거부한다. 가끔, 난 정말 사료만 주는데 강아지가 사료를 거부한다라는 반려인들이 있다. 이런 경우 가족 구성원 중 누군가 지속적으로 사료 외 다른 음식들을 과도하게 주고 있지 않는지 합리적인 의심해봐야 한다. 해결책 1 : 사료 외 다른 음식 급여 중단 반려인으로서 마음이 아프지만, 사료 외 다른 음식의 급여를 중단 하는 수 밖에 없다. 강아지가 요리 중에 측은한 눈빛으로 바라보더라도, 외면할
# 🔢 10 | 🐶 쫑이 | ❓질문: 밥을 잘 안 먹고 사료를 입에 넣었다 뱉어요. 입 안에... | 🕒 응답시간: 20.546s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 밤마다 짖고 깨서 잠을 잘 못 자요. 불면증 같은 게 ... | 🕒 응답시간: 26.066s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 식사 후 구토를 자주 해요. 위장이 약한 걸까요?... | 🕒 응답시간: 25.235s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 물을 거의 안 마셔요. 탈수 걱정해도 될까요?... | 🕒 응답시간: 15.807s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 밥을 잘 안 먹어요. 입맛이 없는 걸까요? 편식일까요?... | 🕒 응답시간: 14.155s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 잠자는 시간이 너무 많아졌어요. 왜 그럴까요?... | 🕒 응답시간: 12.44s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 앉아, 기다려 같은 기본 훈련을 잘 안들어요.... | 🕒 응답시간: 12.89s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 하네스를 차려고 하면 도망가요. 외출이 싫은 걸까요?... | 🕒 응답시간: 18.658s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 차를 타면 자꾸 구토해요. 어떻게 훈련하면 좋을까요?... | 🕒 응답시간: 22.593s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 목줄만 보면 도망가요. 산책을 싫어하는 걸까요?... | 🕒 응답시간: 20.004s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 산책 중에 자꾸 바닥에 있는 걸 주워 먹어요. 위험하지... | 🕒 응답시간: 18.278s
#
# 🧾 [모델 분류 출력]: 카테고리: 지식 탐색
#
# 📌 분류된 카테고리: 지식 탐색
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 계단 오르내릴 때 다리를 절어요. 관절 문제일 수 있나... | 🕒 응답시간: 14.201s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# 🔍 search_documents - RAG 검색된 문서:
#  없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ 이유 4. 반갑다멍 강아지는 너무 반가울 때도 낑낑거려요. 몽이는 초인종 소리가 들리면 그때부터 낑낑거리면서 꼬리를 흔들고 좋아해요. 가족들이 외출했다 들어왔을 때도 낑~ 하는 소리를 내곤 합니다 ㅎㅎ 이때, 강아지가 너무 흥분해서 소변을 흘릴 수도 있어요. 흥분으로 인한 소변 실수는 보통 아직 덜 성숙한 어린 강아지가 종종 하는 행동이에요. 이런 행동은 시간이 지나면서 점점 나아지게 된답니다. 하지만, 다 큰 강아지가 계속해서소변 실수를 한다면, 흥분을 가라앉힐 수 있도록 무시하는 등 훈련을 통해 고쳐주는 게 좋습니다.
#
# 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수 있어요. 제가 반려하고 있는 몽이의 경우 산책에 가고 싶을 때 현관 앞에서 낑낑거린답니다 ㅎㅎ 이유 2. 불안하다멍 강아지는 불안하거나 두려운 상황에서도 낑낑거리는 소리를 내곤 하는데요. 낯선 곳에 가거나 새로운 사람을 만났을 때 겁을 먹으면 이런 행동을 할 수 있습니다. 무섭고 불안하다는 의미에서 낑낑 소리를 내는 거죠. 또한, 보호자가 집을 나설 때 낑낑거릴 수 있어요. 이런 경우분리불안이 있다는 의미일 수 있습니다. 만약 분리불안으로 인한 다른 행동이 함께 보이는지 확인해보고, 맞다면 이를 해결할 수 있도록 노력해야 해요. 이유 3. 아프다멍 강아지는 아플 때도 낑낑 소리를 낼 수 있어요. 예를 들어, 갑자기 계단이나 소파를 오를 때 낑낑거린다면 관절이 약해졌다는 의미일 수 있어요. 아픈 경우강아지의 움직임이 줄어들고 기운도 없어지는데요. 만약 이런 상황이 계속된다면 병원에 가서 진찰을 받도록 해야 합니다 ㅠㅠ
#
# 강아지 낑낑 소리 속 숨겨진 의미는? - 강아지 낑낑, 끙끙 소리는 흔히 들을 수 있는 소리예요. 이런 낑낑 소리 속에는 다양한 의미가 있는데요. 강아지가 어떤 걸 말하려고 하는지 쉽게 알 수 있을 때도 있지만, 그렇지 않은 경우도 있어요. 어떤 이유가 있는지 정확히 알아보도록 해요. 강아지가 낑낑거리는 이유는? 강아지 낑낑 소리, 상황에 따라 달라 강아지 낑낑 소리에는 다양한 의미가 있어요. 같은 낑낑 소리여도, 그 의미는 상황에 따라 달라지는데요. 낑낑거리는 이유 4가지와 그 상황에 대해서 알아보도록 해요. 이유 1. 원하는 게 있다멍 강아지는 원하는 게 있을 때 낑낑 소리를 내며 의사 표현을 하곤 해요. 종종 강아지가 간식을 먹고 싶을 때,장난감이 소파 밑으로 들어갔을 때와 같은 상황에 낑낑거릴 때가 있죠. 이처럼 스스로 해결할 수 없는 일이 생겼을 때 낑낑 소리를 내며 보호자에게 도움을 요청하게 돼요. 또한, 놀고 싶거나 관심이 필요할 때도 낑낑거릴 수 있는데요. 자신을 봐달라는 의미로 볼 수
# 🔢 10 | 🐶 쫑이 | ❓질문: 다른 강아지와 놀다가 갑자기 낑낑거려요. 왜 그런건가요... | 🕒 응답시간: 18.952s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 발을 만지려고 하면 극도로 싫어하고 물려고 해요. 왜 ... | 🕒 응답시간: 21.782s
#
# 🧾 [모델 분류 출력]: 카테고리: 행동 교정
#
# 📌 분류된 카테고리: 행동 교정
# ⚠️ search_documents - RAG 유사한 문서가 없습니다.
# 🔢 10 | 🐶 쫑이 | ❓질문: 가족 중 특정한 사람만 따라다니고, 다른 사람은 피해요... | 🕒 응답시간: 23.904s

# %% [markdown]
# ## 5. 결과 저장

# %%
df = pd.DataFrame(results)
df.to_csv("./qwen_results.csv", index=False, encoding="utf-8-sig")
